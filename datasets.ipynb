# %%
import os
import pandas as pd
from sodapy import Socrata
import requests
from bs4 import BeautifulSoup
import time
from dotenv import load_dotenv

from domain import Domain

# %% [markdown]
# Dataset: https://{domain}/resource/{identifier}.json | The dataset as a json
#
# Count: https://{domain}/views.json?count=True | The count of datasets in the domain
#
# Schema: https://{domain}/views/{identifier}.json | The schema of the given dataset (identifier)
#
# Metadata: https://{domain}/views.json?limit=200&page=1 | The metadata of the datasets in the domain (list of objects representing the datasets)

# %%
nyc_domain = "data.cityofnewyork.us"

domain = Domain(nyc_domain)

print(domain.city_datasets_count()) # currently 2994 returned from getting the count for data.cityofnewyork.us
print(domain.write_dataset_ids_to_file()) # length should be same as count
# Out:
# 'data.cityofnewyork.us_ids.txt'

# %%
nola_domain = "data.nola.gov"

nola = Domain(nola_domain)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
print(nola.city_datasets_count()) 
print(nola.write_dataset_ids_to_file()) # length should be same as count
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# 272
# data.nola.gov\data.nola.gov_ids.txt

# %%
nola.download_all_raw_dataset()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 nola.download_all_raw_dataset()
#
# File c:\Users\jlcha\Python Projects\Big-Data\Big-Data-Final-Project\domain.py:49, in Domain.download_all_raw_dataset(self)
#      47 for line in f:
#      48     dataset_id = line.strip()
# ---> 49     self.download_raw_dataset(dataset_id)
#
# File c:\Users\jlcha\Python Projects\Big-Data\Big-Data-Final-Project\domain.py:57, in Domain.download_raw_dataset(self, dataset_id, outfile)
#      52 url = f"https://{self.domain}/resource/{dataset_id}.json"
#      53 resp = requests.get(
#      54     url,
#      55     timeout=15
#      56 )
# ---> 57 resp.raise_for_status()
#      58 if not outfile:
#      59     outfile = f"data_{dataset_id}.json"
#
# File c:\Users\jlcha\Python Projects\Big-Data\Big-Data-Final-Project\.venv\Lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://data.nola.gov/resource/6a26-q6dq.json

# %%
nola_dataset_identifier = "fcuq-eeca"
nola_client = Socrata(nola_domain, None)
nola_results = nola_client.get(nola_dataset_identifier)
nola_df = pd.DataFrame.from_dict(nola_results)
print("Domain: {domain:}\nSession: {session:}\nURI Prefix: {uri_prefix:}".format(**nola_client.__dict__))
print(nola_df.shape)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# Domain: data.nola.gov
# Session: <requests.sessions.Session object at 0x000002461EDAC100>
# URI Prefix: https://
# (1000, 97)

# %%
nola_results
# Out:
# [{'the_geom': {'type': 'Point',
#    'coordinates': [-90.00833116899997, 29.965332062000073]},
#   'objectid': '1',
#   'gps_id': 'ca00107',
#   'cultural_r': '{0F7ACC9C-A57F-45db-A71C-532A77B0DF1F}',
#   'location_i': '{D447780B-34A9-4474-BB25-4853E96B773C}',
#   'survey_id': '{58FD1A36-0E60-41d7-8FDF-EC037D60D827}',
#   'boundary_t': '6',
#   'map_method': '1',
#   'source': 'GPS',
#   'source_dat': '2005-12-20T00:00:00.000',
#   'source_d_1': '3',
#   'source_coo': '1',
#   'source_acc': '+/- 5 meters',
#   'last_updat': '2006-01-25T00:00:00.000',
#   'restrict_s': '1',
#   'street_num': '1625',
#   'street_nam': 'Tupelo Street',
#   'city_tag': 'red',
#   'city_datab': 'bldg on city list',
#   'constructi': '1930-50',
#   'date_estim': 'Yes',
#   'less_than_': 'no',
#   'listed_sta': 'none',
#   'contribute': 'No',
#   'significan': 'none',
#   'materials_': 'no',
#   'design_int': 'no',
#   'wrkmanship': 'no',
#   'setting_in': 'yes',
#   'location_1': 'no',
#   'foundatio2': 'building off',
#   'wall_condi': 'intact',
#   'roof_condi': 'damaged',
#   'damage_typ': 'multiple',
#   'current_us': 'single dwelling',
#   'style': 'unknown',
#   'building_t': 'bungalow',
#   'footprint': 'rectangular',
#   'height': '1',
#   'foundation': 'concrete pier',
#   'const_mate': 'frame',
#   'cladding': 'unknown',
#   'roof_mate': 'asphalt shingle',
#   'roof_type': 'hip',
#   'chimneys': 'none',
#   'porches': 'full width',
#   'point_reco': 'entrance',
#   'outbuildin': 'not surveyed',
#   'comment': 'red tag',
#   'eligibilit': 'not Nat.Reg.eligible',
#   'shpo_concu': '1',
#   'fema_deter': '2',
#   'shpo_revie': 'Lori Durio, SHPO',
#   'fema_revie': 'Claudia Watson, FEMA',
#   'concur_dat': '2006-04-17T00:00:00.000',
#   'review_com': 'Lack of Significance',
#   'collapsed_': '4',
#   'surveyor_n': 'Coastal Environments',
#   'photograph': 'Coastal Environments',
#   'photo1': '545.JPG',
#   'photo1path': 'https://gisimage.nola.gov/Section106/58FD1/CA1220/545.JPG',
#   'photo2path': 'https://gisimage.nola.gov/Section106/58FD1/CA1220/',
#   'photo3path': 'https://gisimage.nola.gov/Section106/58FD1/CA1220/',
#   'photo4path': 'https://gisimage.nola.gov/Section106/58FD1/CA1220/',
#   'photofile': 'CA1220',
#   'corr_type': 'Real-time SBAS Corrected',
#   'rcvr_type': 'GeoXT',
#   'gps_date': '2005-12-20T00:00:00.000',
#   'gps_time': '09:34:09am',
#   'update_sta': 'New',
#   'feat_nam': 'Buildin2',
#   'datafile': 'CA1220F01.SSF',
#   'unfilt_pos': '11',
#   'data_dicti': 'Katrina_Survey_v2',
#   'latitude': '29.965332183',
#   'longitude': '-90.008331458',
#   'prob_zone': 'Moderate',
#   'd_zone': '17 E-12',
#   'd_list': 'C',
#   'shpo_consu': '5/25/2006',
#   'arch_tier': 'T0',
#   'zipcode': '70117',
#   'address': '1625 Tupelo Street',
#   'demostatus': 'USACE 9/6/2006',
#   'st_num': '1625',
#   'st_name': 'Tupelo',
#   'st_suffix': 'Street',
#   'location_2': {'type': 'Point',
#    'coordinates': [-90.008331458, 29.965332183]}},
#  {'the_geom': {'type': 'Point',
#    'coordinates': [-90.00849916899995, 29.96517606200007]},
#   'objectid': '2',
#   'gps_id': 'ca00109',
#   'cultural_r': '{36FAF0EC-C25F-482b-9617-9B5BDB68117F}',
#   'location_i': '{4B81BC10-9823-4cc8-AFCF-E69BFD4DD642}',
#   'survey_id': '{58FD1A36-0E60-41d7-8FDF-EC037D60D827}',
#   'boundary_t': '8',
#   'map_method': '1',
#   'source': 'GPS',
#   'source_dat': '2005-12-20T00:00:00.000',
#   'source_d_1': '3',
#   'source_coo': '1',
#   'source_acc': '+/- 5 meters',
#   'last_updat': '2006-01-25T00:00:00.000',
#   'restrict_s': '1',
#   'street_num': '1621',
#   'street_nam': 'Tupelo Street',
#   'city_tag': 'red',
#   'city_datab': 'bldg not on city list',
#   'constructi': '1940-55',
#   'date_estim': 'Yes',
#   'less_than_': 'no',
#   'listed_sta': 'none',
#   'contribute': 'No',
#   'significan': 'none',
#   'materials_': 'yes',
#   'design_int': 'yes',
#   'wrkmanship': 'yes',
#   'setting_in': 'yes',
#   'location_1': 'yes',
#   'foundatio2': 'intact',
#   'wall_condi': 'intact',
#   'roof_condi': 'intact',
#   'damage_typ': 'multiple',
#   'current_us': 'unknown',
#   'style': 'unknown',
#   'building_t': 'bungalow',
#   'footprint': 'rectangular',
#   'height': '1',
#   'foundation': 'continuous concrete',
#   'const_mate': 'frame',
#   'cladding': 'unknown',
#   'roof_mate': 'asphalt shingle',
#   'roof_type': 'hip',
#   'chimneys': 'none',
#   'porches': 'stoop',
#   'point_reco': 'northwest corner',
#   'outbuildin': 'not surveyed',
#   'comment': 'red tag not on list',
#   'eligibilit': 'not Nat.Reg.eligible',
#   'shpo_concu': '1',
#   'fema_deter': '2',
#   'shpo_revie': 'Lori Durio, SHPO',
#   'fema_revie': 'Marvin Brown, FEMA',
#   'concur_dat': '2006-10-03T00:00:00.000',
#   'review_com': 'Lack of significance',
#   'collapsed_': '3',
#   'surveyor_n': 'Coastal Environments',
#   'photograph': 'Coastal Environments',
#   'photo1': '546.JPG',
#   'photo1path': 'https://gisimage.nola.gov/Section106/58FD1/CA1220/546.JPG',
#   'photo2path': 'https://gisimage.nola.gov/Section106/58FD1/CA1220/',
#   'photo3path': 'https://gisimage.nola.gov/Section106/58FD1/CA1220/',
#   'photo4path': 'https://gisimage.nola.gov/Section106/58FD1/CA1220/',
#   'photofile': 'CA1220',
#   'corr_type': 'Real-time SBAS Corrected',
#   'rcvr_type': 'GeoXT',
#   'gps_date': '2005-12-20T00:00:00.000',
#   'gps_time': '09:47:53am',
#   'update_sta': 'New',
#   'feat_nam': 'Buildin2',
#   'datafile': 'CA1220F01.SSF',
#   'unfilt_pos': '12',
#   'data_dicti': 'Katrina_Survey_v2',
#   'latitude': '29.965176155',
#   'longitude': '-90.008498826',
#   'prob_zone': 'Moderate',
#   'd_zone': '17 E-12',
#   'd_list': 'H',
#   'shpo_consu': '1/23/2007',
#   'arch_tier': 'T0',
#   'zipcode': '70117',
#   'address': '1621 Tupelo Street',
#   'demostatus': 'no information provided',
#   'st_num': '1621',
#   'st_name': 'Tupelo',
#   'st_suffix': 'Street',
#   'location_2': {'type': 'Point',
#    'coordinates': [-90.008498826, 29.965176155]}},
#  {'the_geom': {'type': 'Point',
#    'coordinates': [-90.00803416899998, 29.965860062000047]},
#   'objectid': '3',
#   'gps_id': 'ca00110',
#   'cultural_r': '{6BDE2051-209E-4f61-8081-B305286B8EA4}',
#   'location_i': '{134EBA13-9CCD-4c97-B12D-D46E9351A923}',
#   'survey_id': '{58FD1A36-0E60-41d7-8FDF-EC037D60D827}',
#   'boundary_t': '8',
#   'map_method': '1',
#   'source': 'GPS',
#   'source_dat': '2005-12-20T00:00:00.000',
#   'source_d_1': '3',
#   'source_coo': '1',
#   'source_acc': '+/- 5 meters',
#   'last_updat': '2006-01-25T00:00:00.000',
#   'restrict_s': '1',
#   'street_num': '1709',
#   'street_nam': 'Tupelo Street',
#   'city_tag': 'red',
#   'city_datab': 'bldg on city list',
#   'constructi': '1940-55',
#   'date_estim': 'Yes',
#   'less_than_': 'no',
#   'listed_sta': 'none',
#   'contribute': 'No',
#   'significan': 'none',
#   'materials_': 'yes',
#   'design_int': 'yes',
#   'wrkmanship': 'yes',
#   'setting_in': 'yes',
#   'location_1': 'no',
#   'foundatio2': 'building off',
#   'wall_condi': 'intact',
#   'roof_condi': 'damaged',
#   'damage_typ': 'multiple',
#   'current_us': 'single dwelling',
#   'style': 'unknown',
#   'building_t': 'bungalow',
#   'footprint': 'rectangular',
#   'height': '1',
#   'foundation': 'concrete pier',
#   'const_mate': 'frame',
#   'cladding': 'unknown',
#   'roof_mate': 'asphalt shingle',
#   'roof_type': 'hip',
#   'chimneys': 'none',
#   'porches': 'partial width',
#   'point_reco': 'northwest corner',
#   'outbuildin': 'not surveyed',
#   'comment': 'red tag, off foundation',
#   'eligibilit': 'not Nat.Reg.eligible',
#   'shpo_concu': '1',
#   'fema_deter': '2',
#   'shpo_revie': 'Lori Durio, SHPO',
#   'fema_revie': 'Claudia Watson, FEMA',
#   'concur_dat': '2006-04-17T00:00:00.000',
#   'review_com': 'Lack of Significance',
#   'collapsed_': '4',
#   'surveyor_n': 'Coastal Environments',
#   'photograph': 'Coastal Environments',
#   'photo1': '547.JPG',
#   'photo2': '548.JPG',
#   'photo1path': 'https://gisimage.nola.gov/Section106/58FD1/CA1220/547.JPG',
#   'photo2path': 'https://gisimage.nola.gov/Section106/58FD1/CA1220/548.JPG',
#   'photo3path': 'https://gisimage.nola.gov/Section106/58FD1/CA1220/',
#   'photo4path': 'https://gisimage.nola.gov/Section106/58FD1/CA1220/',
#   'photofile': 'CA1220',
#   'corr_type': 'Real-time SBAS Corrected',
#   'rcvr_type': 'GeoXT',
#   'gps_date': '2005-12-20T00:00:00.000',
#   'gps_time': '09:54:08am',
#   'update_sta': 'New',
#   'feat_nam': 'Buildin2',
#   'datafile': 'CA1220F01.SSF',
#   'unfilt_pos': '11',
#   'data_dicti': 'Katrina_Survey_v2',
#   'latitude': '29.965860414',
#   'longitude': '-90.008033937',
#   'prob_zone': 'Moderate',
#   'd_zone': '17 E-12',
#   'd_list': 'C',
#   'shpo_consu': '6/22/2006',
#   'arch_tier': 'T0',
#   'zipcode': '70117',
#   'address': '1709 Tupelo Street',
#   'demostatus': 'USACE 7/27/2006',
#   'st_num': '1709',
#   'st_name': 'Tupelo',
#   'st_suffix': 'Street',
#   'location_2': {'type': 'Point',
#    'coordinates': [-90.008033937, 29.965860414]}},
#  {'the_geom': {'type': 'Point',
#    'coordinates': [-90.00800516899994, 29.96620006200004]},
#   'objectid': '4',
#   'gps_id': 'ca00112',
#   'cultural_r': '{DC7DDCAD-3217-402b-92EB-A81A9D5817CE}',
#   'location_i': '{0E1CFF91-3274-4489-8498-FEB2AB3FE47E}',
#   'survey_id': '{58FD1A36-0E60-41d7-8FDF-EC037D60D827}',
#   'boundary_t': '6',
#   'map_method': '1',
#   'source': 'GPS',
#   'source_dat': '2005-12-20T00:00:00.000',
#   'source_d_1': '3',
#   'source_coo': '1',
#   'source_acc': '+/- 5 meters',
#   'last_updat': '2006-01-25T00:00:00.000',
#   'restrict_s': '1',
#   'street_num': '1727',
#   'street_nam': 'Tupelo Street',
#   'city_tag': 'none',
#   'city_datab': 'bldg on city list',
#   'constructi': '1940-55',
#   'date_estim': 'Yes',
#   'less_than_': 'no',
#   'listed_sta': 'none',
#   'contribute': 'No',
#   'significan': 'none',
#   'materials_': 'no',
#   'design_int': 'no',
#   'wrkmanship': 'no',
#   'setting_in': 'no',
#   'location_1': 'no',
#   'foundatio2': 'building off',
#   'wall_condi': 'racked',
#   'roof_condi': 'damaged',
#   'damage_typ': 'multiple',
#   'current_us': 'single dwelling',
#   'style': 'unknown',
#   'building_t': 'bungalow',
#   'footprint': 'rectangular',
#   'height': '1',
#   'foundation': 'continuous concrete',
#   'const_mate': 'frame',
#   'cladding': 'unknown',
#   'roof_mate': 'asphalt shingle',
#   'roof_type': 'hip',
#   'chimneys': 'none',
#   'porches': 'stoop',
#   'point_reco': 'entrance',
#   'outbuildin': 'not surveyed',
#   'comment': 'no red tag, on list',
#   'eligibilit': 'not Nat.Reg.eligible',
#   'shpo_concu': '1',
#   'fema_deter': '2',
#   'shpo_revie': 'Lori Durio, SHPO',
#   'fema_revie': 'Claudia Watson, FEMA',
#   'concur_dat': '2006-04-17T00:00:00.000',
#   'review_com': 'Lack of Significance',
#   'collapsed_': '4',
#   'surveyor_n': 'Coastal Environments',
#   'photograph': 'Coastal Environments',
#   'photo1': '549.JPG',
#   'photo2': '550.JPG',
#   'photo1path': 'https://gisimage.nola.gov/Section106/58FD1/CA1220/549.JPG',
#   'photo2path': 'https://gisimage.nola.gov/Section106/58FD1/CA1220/550.JPG',
#   'photo3path': 'https://gisimage.nola.gov/Section106/58FD1/CA1220/',
#   'photo4path': 'https://gisimage.nola.gov/Section106/58FD1/CA1220/',
#   'photofile': 'CA1220',
#   'corr_type': 'Real-time SBAS Corrected',
#   'rcvr_type': 'GeoXT',
#   'gps_date': '2005-12-20T00:00:00.000',
#   'gps_time': '10:04:11am',
#   'update_sta': 'New',
#   'feat_nam': 'Buildin2',
#   'datafile': 'CA1220F01.SSF',
#   'unfilt_pos': '11',
#   'data_dicti': 'Katrina_Survey_v2',
#   'latitude': '29.966199855',
#   'longitude': '-90.008005498',
#   'prob_zone': 'Moderate',
#   'd_zone': '17 E-12',
#   'd_list': 'C',
#   'shpo_consu': '6/22/2006',
#   'arch_tier': 'T1M',
#   'zipcode': '70117',
#   'address': '1727 Tupelo Street',
#   'demostatus': 'USACE 7/28/2006',
#   'st_num': '1727',
#   'st_name': 'Tupelo',
#   'st_suffix': 'Street',
#   'location_2': {'type': 'Point',
#    'coordinates': [-90.008005498, 29.966199855]}},
#  {'the_geom': {'type': 'Point',
#    'coordinates': [-90.00752116899997, 29.967158062000067]},
#   'objectid': '5',
#   'gps_id': 'ca00113',
#   'cultural_r': '{5834E63D-C0CB-46eb-9DED-13598A6BF37E}',
#   'location_i': '{34880F01-BC2C-4c72-8737-F5162FEFFA20}',
#   'survey_id': '{58FD1A36-0E60-41d7-8FDF-EC037D60D827}',
#   'boundary_t': '8',
#   'map_method': '1',
#   'source': 'GPS',
#   'source_dat': '2005-12-20T00:00:00.000',
#   'source_d_1': '3',
#   'source_coo': '1',
#   'source_acc': '+/- 5 meters',
#   'last_updat': '2006-01-25T00:00:00.000',
#   'restrict_s': '1',
#   'street_num': '1827',
#   'street_nam': 'Tupelo Street',
#   'city_tag': 'none',
#   'city_datab': 'bldg on city list',
#   'constructi': '1940-55',
#   'date_estim': 'Yes',
#   'less_than_': 'no',
#   'listed_sta': 'none',
#   'contribute': 'No',
#   'significan': 'none',
#   'materials_': 'no',
#   'design_int': 'no',
#   'wrkmanship': 'no',
#   'setting_in': 'yes',
#   'location_1': 'yes',
#   'foundatio2': 'building off',
#   'wall_condi': 'racked',
#   'roof_condi': 'damaged',
#   'damage_typ': 'multiple',
#   'current_us': 'unknown',
#   'style': 'unknown',
#   'building_t': 'bungalow',
#   'footprint': 'rectangular',
#   'height': '1',
#   'foundation': 'unknown',
#   'const_mate': 'frame',
#   'cladding': 'unknown',
#   'roof_mate': 'asphalt shingle',
#   'roof_type': 'hip',
#   'chimneys': 'none',
#   'porches': 'unknown',
#   'point_reco': 'northwest corner',
#   'outbuildin': 'not surveyed',
#   'comment': 'no red tag on list',
#   'eligibilit': 'not Nat.Reg.eligible',
#   'shpo_concu': '1',
#   'fema_deter': '2',
#   'shpo_revie': 'Lori Durio, SHPO',
#   'fema_revie': 'Claudia Watson, FEMA',
#   'concur_dat': '2006-04-17T00:00:00.000',
#   'review_com': 'Lack of Significance',
#   'collapsed_': '4',
#   'surveyor_n': 'Coastal Environments',
#   'photograph': 'Coastal Environments',
#   'photo1': '551.JPG',
#   'photo2': '552.JPG',
#   'photo1path': 'https://gisimage.nola.gov/Section106/58FD1/CA1220/551.JPG',
#   'photo2path': 'https://gisimage.nola.gov/Section106/58FD1/CA1220/552.JPG',
#   'photo3path': 'https://gisimage.nola.gov/Section106/58FD1/CA1220/',
#   'photo4path': 'https://gisimage.nola.gov/Section106/58FD1/CA1220/',
#   'photofile': 'CA1220',
#   'corr_type': 'Real-time SBAS Corrected',
#   'rcvr_type': 'GeoXT',
#   'gps_date': '2005-12-20T00:00:00.000',
#   'gps_time': '10:29:56am',
#   'update_sta': 'New',
#   'feat_nam': 'Buildin2',
#   'datafile': 'CA1220F01.SSF',
#   'unfilt_pos': '11',
#   'data_dicti': 'Katrina_Survey_v2',
#   'latitude': '29.967157800',
#   'longitude': '-90.007521651',
#   'prob_zone': 'Moderate',
#   'd_zone': '17 E-12',
#   'd_list': 'C',
#   'shpo_consu': '6/22/2006',
#   'arch_tier': 'T0',
#   'zipcode': '70117',
#   'address': '1827 Tupelo Street',
#   'demostatus': 'USACE 8/15/2006',
#   'st_num': '1827',
#   'st_name': 'Tupelo',
#   'st_suffix': 'Street',
#   'location_2': {'type': 'Point', 'coordinates': [-90.007521651, 29.9671578]}},
#  {'the_geom': {'type': 'Point',
#    'coordinates': [-90.00650716899997, 29.969323062000058]},
#   'objectid': '6',
#   'gps_id': 'ca00114',
#   'cultural_r': '{9EE16D79-E8E6-45b7-AD55-9D36277FC896}',
#   'location_i': '{1CA3946A-68D6-4f86-AF38-030F2828074A}',
#   'survey_id': '{58FD1A36-0E60-41d7-8FDF-EC037D60D827}',
#   'boundary_t': '6',
#   'map_method': '1',
#   'source': 'GPS',
#   'source_dat': '2005-12-20T00:00:00.000',
#   'source_d_1': '3',
#   'source_coo': '1',
#   'source_acc': '+/- 5 meters',
#   'last_updat': '2006-01-25T00:00:00.000',
#   'restrict_s': '1',
#   'street_num': '2033',
#   'street_nam': 'Tupelo Street',
#   'city_tag': 'red',
#   'city_datab': 'bldg on city list',
#   'constructi': '1930-50',
#   'date_estim': 'Yes',
#   'less_than_': 'no',
#   'listed_sta': 'none',
#   'contribute': 'No',
#   'significan': 'none',
#   'materials_': 'no',
#   'design_int': 'no',
#   'wrkmanship': 'no',
#   'setting_in': 'yes',
#   'location_1': 'yes',
#   'foundatio2': 'building off',
#   'wall_condi': 'racked',
#   'roof_condi': 'damaged',
#   'damage_typ': 'multiple',
#   'current_us': 'single dwelling',
#   'style': 'unknown',
#   'building_t': 'bungalow',
#   'footprint': 'rectangular',
#   'height': '1',
#   'foundation': 'unknown',
#   'const_mate': 'frame',
#   'cladding': 'unknown',
#   'roof_mate': 'asphalt shingle',
#   'roof_type': 'front gable',
#   'chimneys': 'none',
#   'porches': 'partial width',
#   'point_reco': 'entrance',
#   'outbuildin': 'not surveyed',
#   'comment': 'red tag',
#   'eligibilit': 'not Nat.Reg.eligible',
#   'shpo_concu': '1',
#   'fema_deter': '2',
#   'shpo_revie': 'Lori Durio, SHPO',
#   'fema_revie': 'Claudia Watson, FEMA',
#   'concur_dat': '2006-04-17T00:00:00.000',
#   'review_com': 'Lack of Significance',
#   'collapsed_': '4',
#   'surveyor_n': 'Coastal Environments',
#   'photograph': 'Coastal Environments',
#   'photo1': '553.JPG',
#   'photo2': '554.JPG',
#   'photo1path': 'https://gisimage.nola.gov/Section106/58FD1/CA1220/553.JPG',
#   'photo2path': 'https://gisimage.nola.gov/Section106/58FD1/CA1220/554.JPG',
#   'photo3path': 'https://gisimage.nola.gov/Section106/58FD1/CA1220/',
#   'photo4path': 'https://gisimage.nola.gov/Section106/58FD1/CA1220/',
#   'photofile': 'CA1220',
#   'corr_type': 'Uncorrected',
#   'rcvr_type': 'GeoXT',
#   'gps_date': '2005-12-20T00:00:00.000',
#   'gps_time': '10:38:24am',
#   'update_sta': 'New',
#   'feat_nam': 'Buildin2',
#   'datafile': 'CA1220F01.SSF',
#   'unfilt_pos': '11',
#   'data_dicti': 'Katrina_Survey_v2',
#   'latitude': '29.969323164',
#   'longitude': '-90.006507416',
#   'prob_zone': 'Moderate',
#   'd_zone': '17 E-11',
#   'd_list': 'C',
#   'shpo_consu': '6/22/2006',
#   'arch_tier': 'T0',
#   'zipcode': '70117',
#   'address': '2033 Tupelo Street',
#   'demostatus': 'USACE 8/18/2006',
#   'st_num': '2033',
#   'st_name': 'Tupelo',
#   'st_suffix': 'Street',
#   'location_2': {'type': 'Point',
#    'coordinates': [-90.006507416, 29.969323164]}},
#  {'the_geom': {'type': 'Point',
#    'coordinates': [-90.00621816899996, 29.969944062000025]},
#   'objectid': '7',
#   'gps_id': 'ca00115',
#   'cultural_r': '{C6F4BB1E-0296-43ea-9919-89F9B1C616A2}',
#   'location_i': '{36B40957-7D22-4cb6-AB20-39D070B90399}',
#   'survey_id': '{58FD1A36-0E60-41d7-8FDF-EC037D60D827}',
#   'boundary_t': '6',
#   'map_method': '1',
#   'source': 'GPS',
#   'source_dat': '2005-12-20T00:00:00.000',
#   'source_d_1': '3',
#   'source_coo': '1',
#   'source_acc': '+/- 5 meters',
#   'last_updat': '2006-01-25T00:00:00.000',
#   'restrict_s': '1',
#   'street_num': '2115',
#   'street_nam': 'Tupelo Street',
#   'city_tag': 'red',
#   'city_datab': 'bldg on city list',
#   'constructi': '1940-55',
#   'date_estim': 'Yes',
#   'less_than_': 'no',
#   'listed_sta': 'none',
#   'contribute': 'No',
#   'significan': 'none',
#   'materials_': 'no',
#   'design_int': 'no',
#   'wrkmanship': 'no',
#   'setting_in': 'yes',
#   'location_1': 'yes',
#   'foundatio2': 'building off',
#   'wall_condi': 'racked',
#   'roof_condi': 'damaged',
#   'damage_typ': 'multiple',
#   'current_us': 'single dwelling',
#   'style': 'unknown',
#   'building_t': 'bungalow',
#   'footprint': 'rectangular',
#   'height': '1',
#   'foundation': 'concrete pier',
#   'const_mate': 'frame',
#   'cladding': 'unknown',
#   'roof_mate': 'asphalt shingle',
#   'roof_type': 'side gable',
#   'chimneys': 'none',
#   'porches': 'partial width',
#   'point_reco': 'entrance',
#   'outbuildin': 'not surveyed',
#   'comment': 'red tag',
#   'eligibilit': 'not Nat.Reg.eligible',
#   'shpo_concu': '1',
#   'fema_deter': '2',
#   'shpo_revie': 'Lori Durio, SHPO',
#   'fema_revie': 'Claudia Watson, FEMA',
#   'concur_dat': '2006-04-17T00:00:00.000',
#   'review_com': 'Lack of Significance',
#   'collapsed_': '4',
#   'surveyor_n': 'Coastal Environments',
#   'photograph': 'Coastal Environments',
#   'photo1': '555.JPG',
#   'photo2': '556.JPG',
#   'photo1path': 'https://gisimage.nola.gov/Section106/58FD1/CA1220/555.JPG',
#   'photo2path': 'https://gisimage.nola.gov/Section106/58FD1/CA1220/556.JPG',
#   'photo3path': 'https://gisimage.nola.gov/Section106/58FD1/CA1220/',
#   'photo4path': 'https://gisimage.nola.gov/Section106/58FD1/CA1220/',
#   'photofile': 'CA1220',
#   'corr_type': 'Uncorrected',
#   'rcvr_type': 'GeoXT',
#   'gps_date': '2005-12-20T00:00:00.000',
#   'gps_time': '10:47:05am',
#   'update_sta': 'New',
#   'feat_nam': 'Buildin2',
#   'datafile': 'CA1220F01.SSF',
#   'unfilt_pos': '12',
#   'data_dicti': 'Katrina_Survey_v2',
#   'latitude': '29.969944418',
#   'longitude': '-90.006218666',
#   'prob_zone': 'Moderate',
#   'd_zone': '17 E-10',
#   'd_list': 'C',
#   'shpo_consu': '6/22/2006',
#   'arch_tier': 'T0',
#   'zipcode': '70117',
#   'address': '2115 Tupelo Street',
#   'demostatus': 'USACE 7/29/2006',
#   'st_num': '2115',
#   'st_name': 'Tupelo',
#   'st_suffix': 'Street',
#   'location_2': {'type': 'Point',
#    'coordinates': [-90.006218666, 29.969944418]}},
#  {'the_geom': {'type': 'Point',
#    'coordinates': [-90.01248916899999, 29.971689062000053]},
#   'objectid': '8',
#   'gps_id': 'gc00122',
#   'cultural_r': '{DBB14FC6-0A66-40c3-AAAC-152095FCB7E3}',
#   'location_i': '{D5624F8E-EAD6-4a46-BFF2-FCAAC63BC262}',
#   'survey_id': '{58FD1A36-0E60-41d7-8FDF-EC037D60D827}',
#   'boundary_t': '6',
#   'map_method': '1',
#   'source': 'GPS',
#   'source_dat': '2005-12-21T00:00:00.000',
#   'source_d_1': '3',
#   'source_coo': '1',
#   'source_acc': '+/- 5 meters',
#   'last_updat': '2006-01-25T00:00:00.000',
#   'restrict_s': '1',
#   'street_num': '2110',
#   'street_nam': 'Caffin Avenue',
#   'city_tag': 'red',
#   'city_datab': 'bldg on city list',
#   'constructi': 'Unknown',
#   'date_estim': 'Yes',
#   'less_than_': 'unsure',
#   'listed_sta': 'Unknown',
#   'contribute': 'No',
#   'significan': 'unknown',
#   'materials_': 'no',
#   'design_int': 'yes',
#   'wrkmanship': 'no',
#   'setting_in': 'no',
#   'location_1': 'no',
#   'foundatio2': 'building off',
#   'wall_condi': 'racked',
#   'roof_condi': 'damaged',
#   'damage_typ': 'multiple',
#   'current_us': 'single dwelling',
#   'style': 'other',
#   'building_t': 'other',
#   'footprint': 'rectangular',
#   'height': '1',
#   'foundation': 'unknown',
#   'const_mate': 'frame',
#   'cladding': 'unknown',
#   'roof_mate': 'asbestos shingle',
#   'roof_type': 'hip',
#   'chimneys': 'unknown',
#   'porches': 'none',
#   'point_reco': 'entrance',
#   'outbuildin': 'not surveyed',
#   'comment': 'Off lot',
#   'eligibilit': 'not Nat.Reg.eligible',
#   'shpo_concu': '1',
#   'fema_deter': '2',
#   'shpo_revie': 'Lori Durio, SHPO',
#   'fema_revie': 'Claudia Watson, FEMA',
#   'concur_dat': '2006-04-13T00:00:00.000',
#   'review_com': 'Lack of Significance',
#   'collapsed_': '4',
#   'surveyor_n': 'Goodwin and Associates',
#   'photograph': 'Goodwin and Associates',
#   'photo1': 'PC200012.JPG',
#   'photo1path': 'https://gisimage.nola.gov/Section106/58FD1/GC1221/PC200012.JPG',
#   'photo2path': 'https://gisimage.nola.gov/Section106/58FD1/GC1221/',
#   'photo3path': 'https://gisimage.nola.gov/Section106/58FD1/GC1221/',
#   'photo4path': 'https://gisimage.nola.gov/Section106/58FD1/GC1221/',
#   'photofile': 'GC1221',
#   'corr_type': 'Uncorrected',
#   'rcvr_type': 'GeoXM',
#   'gps_date': '2005-12-21T00:00:00.000',
#   'gps_time': '02:12:26pm',
#   'update_sta': 'New',
#   'feat_nam': 'Buildin2',
#   'datafile': 'GC1221F02.SSF',
#   'unfilt_pos': '10',
#   'data_dicti': 'Katrina_Survey_v2',
#   'latitude': '29.971689079',
#   'longitude': '-90.012488816',
#   'prob_zone': 'Moderate',
#   'd_zone': '17 D-10',
#   'd_list': 'C',
#   'shpo_consu': '6/22/2006',
#   'arch_tier': 'T1M',
#   'zipcode': '70117',
#   'address': '2110 Caffin Avenue',
#   'demostatus': 'USACE 8/7/2006',
#   'st_num': '2110',
#   'st_name': 'Caffin',
#   'st_suffix': 'Avenue',
#   'location_2': {'type': 'Point',
#    'coordinates': [-90.012488816, 29.971689079]}},
#  {'the_geom': {'type': 'Point',
#    'coordinates': [-90.01256716899996, 29.971906062000073]},
#   'objectid': '9',
#   'gps_id': 'gc00223',
#   'cultural_r': '{58A426C8-02D0-4a59-A420-848C5FB7ED55}',
#   'location_i': '{AF5D966B-5ADE-4073-A457-1270C6884115}',
#   'survey_id': '{58FD1A36-0E60-41d7-8FDF-EC037D60D827}',
#   'boundary_t': '7',
#   'map_method': '1',
#   'source': 'GPS',
#   'source_dat': '2005-12-21T00:00:00.000',
#   'source_d_1': '3',
#   'source_coo': '1',
#   'source_acc': '+/- 5 meters',
#   'last_updat': '2006-01-25T00:00:00.000',
#   'restrict_s': '1',
#   'street_num': '2116-18',
#   'street_nam': 'Caffin Avenue',
#   'city_tag': 'red',
#   'city_datab': 'bldg not on city list',
#   'constructi': '1950',
#   'date_estim': 'Yes',
#   'less_than_': 'no',
#   'listed_sta': 'Unknown',
#   'contribute': 'No',
#   'significan': 'unknown',
#   'materials_': 'yes',
#   'design_int': 'yes',
#   'wrkmanship': 'yes',
#   'setting_in': 'yes',
#   'location_1': 'yes',
#   'foundatio2': 'unknown',
#   'wall_condi': 'partial collapse',
#   'roof_condi': 'damaged',
#   'damage_typ': 'multiple',
#   'current_us': 'multiple dwelling',
#   'style': 'other',
#   'building_t': 'other',
#   'footprint': 'square',
#   'height': '2',
#   'foundation': 'concrete slab',
#   'const_mate': 'brick',
#   'cladding': 'unknown',
#   'roof_mate': 'other',
#   'roof_type': 'multiple',
#   'chimneys': 'none',
#   'porches': 'none',
#   'point_reco': 'center',
#   'outbuildin': 'not surveyed',
#   'comment': 'Dilapidated, rear collapse',
#   'eligibilit': 'not Nat.Reg.eligible',
#   'shpo_concu': '1',
#   'fema_deter': '2',
#   'shpo_revie': 'Mike Varnado, SHPO',
#   'fema_revie': 'Shauna Haas, FEMA',
#   'concur_dat': '2007-05-22T00:00:00.000',
#   'review_com': 'Lack of significance',
#   'collapsed_': '2',
#   'surveyor_n': 'Goodwin and Associates',
#   'photograph': 'Goodwin and Associates',
#   'photo1': 'PC200013.JPG',
#   'photo1path': 'https://gisimage.nola.gov/Section106/58FD1/GC1221/PC200013.JPG',
#   'photo2path': 'https://gisimage.nola.gov/Section106/58FD1/GC1221/',
#   'photo3path': 'https://gisimage.nola.gov/Section106/58FD1/GC1221/',
#   'photo4path': 'https://gisimage.nola.gov/Section106/58FD1/GC1221/',
#   'photofile': 'GC1221',
#   'corr_type': 'Uncorrected',
#   'rcvr_type': 'GeoXM',
#   'gps_date': '2005-12-21T00:00:00.000',
#   'gps_time': '02:20:11pm',
#   'update_sta': 'New',
#   'feat_nam': 'Buildin2',
#   'datafile': 'GC1221F02.SSF',
#   'unfilt_pos': '12',
#   'data_dicti': 'Katrina_Survey_v2',
#   'latitude': '29.971905910',
#   'longitude': '-90.012566939',
#   'prob_zone': 'Moderate',
#   'd_zone': '17 D-10',
#   'd_list': 'M',
#   'shpo_consu': '6/20/2007',
#   'arch_tier': 'T0',
#   'zipcode': '70117',
#   'address': '2116-18 Caffin Avenue',
#   'demostatus': 'USACE 6/28/2007',
#   'st_num': '2116-18',
#   'st_name': 'Caffin',
#   'st_suffix': 'Avenue',
#   'location_2': {'type': 'Point',
#    'coordinates': [-90.012566939, 29.97190591]}},
#  {'the_geom': {'type': 'Point',
#    'coordinates': [-90.01204716899997, 29.971940062000044]},
#   'objectid': '10',
#   'gps_id': 'gc00224',
#   'cultural_r': '{EA666061-7497-464b-9B16-0A890F23349B}',
#   'location_i': '{2626F5DA-1BB3-42d0-938D-510F1755417C}',
#   'survey_id': '{58FD1A36-0E60-41d7-8FDF-EC037D60D827}',
#   'boundary_t': '8',
#   'map_method': '1',
#   'source': 'GPS',
#   'source_dat': '2005-12-21T00:00:00.000',
#   'source_d_1': '3',
#   'source_coo': '1',
#   'source_acc': '+/- 5 meters',
#   'last_updat': '2006-01-25T00:00:00.000',
#   'restrict_s': '1',
#   'street_num': '2325',
#   'street_nam': 'Caffin Avenue',
#   'city_tag': 'red',
#   'city_datab': 'bldg on city list',
#   'constructi': '1930',
#   'date_estim': 'Yes',
#   'less_than_': 'no',
#   'listed_sta': 'Unknown',
#   'contribute': 'No',
#   'significan': 'unknown',
#   'materials_': 'no',
#   'design_int': 'no',
#   'wrkmanship': 'no',
#   'setting_in': 'no',
#   'location_1': 'no',
#   'foundatio2': 'building off',
#   'wall_condi': 'total collapse',
#   'roof_condi': 'total collapse',
#   'damage_typ': 'multiple',
#   'current_us': 'single dwelling',
#   'style': 'unknown',
#   'building_t': 'shotgun',
#   'footprint': 'rectangular',
#   'height': '1',
#   'foundation': 'unknown',
#   'const_mate': 'unknown',
#   'cladding': 'unknown',
#   'roof_mate': 'asbestos shingle',
#   'roof_type': 'front gable',
#   'chimneys': 'none',
#   'porches': 'unknown',
#   'point_reco': 'northwest corner',
#   'outbuildin': 'not surveyed',
#   'comment': 'Only roof visible, rubble',
#   'eligibilit': 'not Nat.Reg.eligible',
#   'shpo_concu': '1',
#   'fema_deter': '2',
#   'shpo_revie': 'Lori Durio, SHPO',
#   'fema_revie': 'Claudia Watson, FEMA',
#   'concur_dat': '2006-03-24T00:00:00.000',
#   'collapsed_': '1',
#   'surveyor_n': 'Goodwin and Associates',
#   'photograph': 'Goodwin and Associates',
#   'photo1': 'PC200014.JPG',
#   'photo1path': 'https://gisimage.nola.gov/Section106/58FD1/GC1221/PC200014.JPG',
#   'photo2path': 'https://gisimage.nola.gov/Section106/58FD1/GC1221/',
#   'photo3path': 'https://gisimage.nola.gov/Section106/58FD1/GC1221/',
#   'photo4path': 'https://gisimage.nola.gov/Section106/58FD1/GC1221/',
#   'photofile': 'GC1221',
#   'corr_type': 'Uncorrected',
#   'rcvr_type': 'GeoXM',
#   'gps_date': '2005-12-21T00:00:00.000',
#   'gps_time': '02:30:28pm',
#   'update_sta': 'New',
#   'feat_nam': 'Buildin2',
#   'datafile': 'GC1221F02.SSF',
#   'unfilt_pos': '10',
#   'data_dicti': 'Katrina_Survey_v2',
#   'latitude': '29.971939725',
#   'longitude': '-90.012046792',
#   'prob_zone': 'Moderate',
#   'd_zone': '17 D-10',
#   'd_list': 'C',
#   'shpo_consu': '7/24/2007',
#   'arch_tier': 'T0',
#   'zipcode': '70117',
#   'address': '2325 Caffin Avenue',
#   'demostatus': 'no information provided',
#   'st_num': '2325',
#   'st_name': 'Caffin',
#   'st_suffix': 'Avenue',
#   'location_2': {'type': 'Point',
#    'coordinates': [-90.012046792, 29.971939725]}},
#  {'the_geom': {'type': 'Point',
#    'coordinates': [-90.01239516899994, 29.971969062000028]},
#   'objectid': '11',
#   'gps_id': 'gc00125',
#   'cultural_r': '{F1135288-89D7-480f-82B9-D8710716980C}',
#   'location_i': '{E1DADF5D-CA1E-4482-9471-CEC8523E7EC4}',
#   'survey_id': '{58FD1A36-0E60-41d7-8FDF-EC037D60D827}',
#   'boundary_t': '6',
#   'map_method': '1',
#   'source': 'GPS',
#   'source_dat': '2005-12-21T00:00:00.000',
#   'source_d_1': '3',
#   'source_coo': '1',
#   'source_acc': '+/- 5 meters',
#   'last_updat': '2006-01-25T00:00:00.000',
#   'restrict_s': '1',
#   'street_num': '2126',
#   'street_nam': 'Caffin Avenue',
#   'city_tag': 'red',
#   'city_datab': 'bldg on city list',
#   'constructi': '1930',
#   'date_estim': 'Yes',
#   'less_than_': 'no',
#   'listed_sta': 'Unknown',
#   'contribute': 'No',
#   'significan': 'unknown',
#   'materials_': 'yes',
#   'design_int': 'no',
#   'wrkmanship': 'no',
#   'setting_in': 'yes',
#   'location_1': 'yes',
#   'foundatio2': 'unknown',
#   'wall_condi': 'unknown',
#   'roof_condi': 'unknown',
#   'damage_typ': 'multiple',
#   'current_us': 'single dwelling',
#   'style': 'other',
#   'building_t': 'shotgun',
#   'footprint': 'rectangular',
#   'height': '1.5',
#   'foundation': 'concrete pier',
#   'const_mate': 'frame',
#   'cladding': 'unknown',
#   'roof_mate': 'asphalt shingle',
#   'roof_type': 'gable on hip',
#   'chimneys': 'unknown',
#   'porches': 'stoop',
#   'point_reco': 'entrance',
#   'outbuildin': 'not surveyed',
#   'comment': 'Front porch collapsed',
#   'eligibilit': 'not Nat.Reg.eligible',
#   'shpo_concu': '1',
#   'fema_deter': '2',
#   'shpo_revie': 'Lori Durio, SHPO',
#   'fema_revie': 'Claudia Watson, FEMA',
#   'concur_dat': '2006-04-13T00:00:00.000',
#   'review_com': 'Lack of Significance',
#   'collapsed_': '4',
#   'surveyor_n': 'Goodwin and Associates',
#   'photograph': 'Goodwin and Associates',
#   'photo1': 'PC200015.JPG',
#   'photo1path': 'https://gisimage.nola.gov/Section106/58FD1/GC1221/PC200015.JPG',
#   'photo2path': 'https://gisimage.nola.gov/Section106/58FD1/GC1221/',
#   'photo3path': 'https://gisimage.nola.gov/Section106/58FD1/GC1221/',
#   'photo4path': 'https://gisimage.nola.gov/Section106/58FD1/GC1221/',
#   'photofile': 'GC1221',
#   'corr_type': 'Uncorrected',
#   'rcvr_type': 'GeoXM',
#   'gps_date': '2005-12-21T00:00:00.000',
#   'gps_time': '02:38:03pm',
#   'update_sta': 'New',
#   'feat_nam': 'Buildin2',
#   'datafile': 'GC1221F02.SSF',
#   'unfilt_pos': '11',
#   'data_dicti': 'Katrina_Survey_v2',
#   'latitude': '29.971969163',
#   'longitude': '-90.012394842',
#   'prob_zone': 'Moderate',
#   'd_zone': '17 D-10',
#   'd_list': 'C',
#   'shpo_consu': '6/22/2006',
#   'arch_tier': 'T0',
#   'zipcode': '70117',
#   'address': '2126 Caffin Avenue',
#   'demostatus': 'USACE 8/10/2006',
#   'st_num': '2126',
#   'st_name': 'Caffin',
#   'st_suffix': 'Avenue',
#   'location_2': {'type': 'Point',
#    'coordinates': [-90.012394842, 29.971969163]}},
#  {'the_geom': {'type': 'Point',
#    'coordinates': [-90.01206116899994, 29.972134062000066]},
#   'objectid': '12',
#   'gps_id': 'gc00126',
#   'cultural_r': '{BE3F0978-3C8D-4d5e-8535-CC09CDC321A1}',
#   'location_i': '{F5566595-6311-4a93-934C-FE513191AA6E}',
#   'survey_id': '{58FD1A36-0E60-41d7-8FDF-EC037D60D827}',
#   'boundary_t': '7',
#   'map_method': '1',
#   'source': 'GPS',
#   'source_dat': '2005-12-21T00:00:00.000',
#   'source_d_1': '3',
#   'source_coo': '1',
#   'source_acc': '+/- 5 meters',
#   'last_updat': '2006-01-25T00:00:00.000',
#   'restrict_s': '1',
#   'street_num': '2133-35',
#   'street_nam': 'Caffin Avenue',
#   'city_tag': 'red',
#   'city_datab': 'bldg on city list',
#   'constructi': '1940',
#   'date_estim': 'Yes',
#   'less_than_': 'no',
#   'listed_sta': 'Unknown',
#   'contribute': 'No',
#   'significan': 'unknown',
#   'materials_': 'yes',
#   'design_int': 'no',
#   'wrkmanship': 'no',
#   'setting_in': 'yes',
#   'location_1': 'no',
#   'foundatio2': 'building off',
#   'wall_condi': 'racked',
#   'roof_condi': 'damaged',
#   'damage_typ': 'multiple',
#   'current_us': 'multiple dwelling',
#   'style': 'other',
#   'building_t': 'other',
#   'footprint': 'rectangular',
#   'height': '1',
#   'foundation': 'concrete pier',
#   'const_mate': 'frame',
#   'cladding': 'unknown',
#   'roof_mate': 'asphalt shingle',
#   'roof_type': 'other',
#   'chimneys': 'unknown',
#   'porches': 'stoop',
#   'point_reco': 'center',
#   'outbuildin': 'not surveyed',
#   'comment': 'Severe structural damage',
#   'eligibilit': 'not Nat.Reg.eligible',
#   'shpo_concu': '1',
#   'fema_deter': '2',
#   'shpo_revie': 'Lori Durio, SHPO',
#   'fema_revie': 'Claudia Watson, FEMA',
#   'concur_dat': '2006-04-13T00:00:00.000',
#   'review_com': 'Lack of Significance',
#   'collapsed_': '4',
#   'surveyor_n': 'Goodwin and Associates',
#   'photograph': 'Goodwin and Associates',
#   'photo1': 'PC200016.JPG',
#   'photo1path': 'https://gisimage.nola.gov/Section106/58FD1/GC1221/PC200016.JPG',
#   'photo2path': 'https://gisimage.nola.gov/Section106/58FD1/GC1221/',
#   'photo3path': 'https://gisimage.nola.gov/Section106/58FD1/GC1221/',
#   'photo4path': 'https://gisimage.nola.gov/Section106/58FD1/GC1221/',
#   'photofile': 'GC1221',
#   'corr_type': 'Uncorrected',
#   'rcvr_type': 'GeoXM',
#   'gps_date': '2005-12-21T00:00:00.000',
#   'gps_time': '02:47:48pm',
#   'update_sta': 'New',
#   'feat_nam': 'Buildin2',
#   'datafile': 'GC1221F02.SSF',
#   'unfilt_pos': '12',
#   'data_dicti': 'Katrina_Survey_v2',
#   'latitude': '29.972134145',
#   'longitude': '-90.012061388',
#   'prob_zone': 'Moderate',
#   'd_zone': '17 D-10',
#   'd_list': 'C',
#   'shpo_consu': '6/22/2006',
#   'arch_tier': 'T0',
#   'zipcode': '70117',
#   'address': '2133-35 Caffin Avenue',
#   'demostatus': 'USACE 8/27/2006',
#   'st_num': '2133-35',
#   'st_name': 'Caffin',
#   'st_suffix': 'Avenue',
#   'location_2': {'type': 'Point',
#    'coordinates': [-90.012061388, 29.972134145]}},
#  {'the_geom': {'type': 'Point',
#    'coordinates': [-90.01239316899995, 29.97228406200003]},
#   'objectid': '13',
#   'gps_id': 'gc00127',
#   'cultural_r': '{1BC2B8B7-A979-456d-80D2-8204C3F4E6DA}',
#   'location_i': '{20493AFD-D75B-4e9f-AA6D-9ECA36C1C843}',
#   'survey_id': '{58FD1A36-0E60-41d7-8FDF-EC037D60D827}',
#   'boundary_t': '7',
#   'map_method': '1',
#   'source': 'GPS',
#   'source_dat': '2005-12-21T00:00:00.000',
#   'source_d_1': '3',
#   'source_coo': '1',
#   'source_acc': '+/- 5 meters',
#   'last_updat': '2006-01-25T00:00:00.000',
#   'restrict_s': '1',
#   'street_num': '2136-38',
#   'street_nam': 'Caffin Avenue',
#   'city_tag': 'red',
#   'city_datab': 'bldg not on city list',
#   'constructi': '1930',
#   'date_estim': 'Yes',
#   'less_than_': 'no',
#   'listed_sta': 'Unknown',
#   'contribute': 'No',
#   'significan': 'unknown',
#   'materials_': 'yes',
#   'design_int': 'yes',
#   'wrkmanship': 'yes',
#   'setting_in': 'yes',
#   'location_1': 'yes',
#   'foundatio2': 'damaged',
#   'wall_condi': 'unknown',
#   'roof_condi': 'damaged',
#   'damage_typ': 'multiple',
#   'current_us': 'multiple dwelling',
#   'style': 'unknown',
#   'building_t': 'double shotgun',
#   'footprint': 'rectangular',
#   'height': '1',
#   'foundation': 'continuous concrete',
#   'const_mate': 'concrete block',
#   'cladding': 'unknown',
#   'roof_mate': 'asbestos shingle',
#   'roof_type': 'front gable',
#   'chimneys': 'none',
#   'porches': 'stoop',
#   'point_reco': 'center',
#   'outbuildin': 'not surveyed',
#   'comment': 'Roof damage',
#   'eligibilit': 'not Nat.Reg.eligible',
#   'shpo_concu': '1',
#   'fema_deter': '2',
#   'shpo_revie': 'Lori Durio, SHPO',
#   'fema_revie': 'Marvin Brown, FEMA',
#   'concur_dat': '2006-11-06T00:00:00.000',
#   'review_com': 'Lack of Significance',
#   'collapsed_': '3',
#   'surveyor_n': 'Goodwin and Associates',
#   'photograph': 'Goodwin and Associates',
#   'photo1': 'PC200017.JPG',
#   'photo1path': 'https://gisimage.nola.gov/Section106/58FD1/GC1221/PC200017.JPG',
#   'photo2path': 'https://gisimage.nola.gov/Section106/58FD1/GC1221/',
#   'photo3path': 'https://gisimage.nola.gov/Section106/58FD1/GC1221/',
#   'photo4path': 'https://gisimage.nola.gov/Section106/58FD1/GC1221/',
#   'photofile': 'GC1221',
#   'corr_type': 'Uncorrected',
#   'rcvr_type': 'GeoXM',
#   'gps_date': '2005-12-21T00:00:00.000',
#   'gps_time': '02:55:18pm',
#   'update_sta': 'New',
#   'feat_nam': 'Buildin2',
#   'datafile': 'GC1221F02.SSF',
#   'unfilt_pos': '12',
#   'data_dicti': 'Katrina_Survey_v2',
#   'latitude': '29.972284156',
#   'longitude': '-90.012393539',
#   'prob_zone': 'Moderate',
#   'd_zone': '17 D-10',
#   'd_list': 'I',
#   'shpo_consu': '1/30/2007',
#   'arch_tier': 'T0',
#   'zipcode': '70117',
#   'address': '2136-38 Caffin Avenue',
#   'demostatus': 'USACE 6/1/2007',
#   'st_num': '2136-38',
#   'st_name': 'Caffin',
#   'st_suffix': 'Avenue',
#   'location_2': {'type': 'Point',
#    'coordinates': [-90.012393539, 29.972284156]}},
#  {'the_geom': {'type': 'Point',
#    'coordinates': [-90.01200416899997, 29.97254606200005]},
#   'objectid': '14',
#   'gps_id': 'gc00128',
#   'cultural_r': '{B186AFBF-0F44-416c-988D-B9CA938678F4}',
#   'location_i': '{8136D953-FF4A-4585-AED3-2CF73586E7CA}',
#   'survey_id': '{58FD1A36-0E60-41d7-8FDF-EC037D60D827}',
#   'boundary_t': '6',
#   'map_method': '1',
#   'source': 'GPS',
#   'source_dat': '2005-12-21T00:00:00.000',
#   'source_d_1': '3',
#   'source_coo': '1',
#   'source_acc': '+/- 5 meters',
#   'last_updat': '2006-01-25T00:00:00.000',
#   'restrict_s': '1',
#   'street_num': '2201',
#   'street_nam': 'Caffin Avenue',
#   'city_tag': 'red',
#   'city_datab': 'bldg not on city list',
#   'constructi': '1950',
#   'date_estim': 'Yes',
#   'less_than_': 'no',
#   'listed_sta': 'Unknown',
#   'contribute': 'No',
#   'significan': 'unknown',
#   'materials_': 'yes',
#   'design_int': 'yes',
#   'wrkmanship': 'yes',
#   'setting_in': 'yes',
#   'location_1': 'yes',
#   'foundatio2': 'damaged',
#   'wall_condi': 'partial collapse',
#   'roof_condi': 'damaged',
#   'damage_typ': 'multiple',
#   'current_us': 'commercial',
#   'style': 'other',
#   'building_t': 'other',
#   'footprint': 'rectangular',
#   'height': '1',
#   'foundation': 'concrete slab',
#   'const_mate': 'brick',
#   'cladding': 'unknown',
#   'roof_mate': 'asphalt shingle',
#   'roof_type': 'hip',
#   'chimneys': 'unknown',
#   'porches': 'none',
#   'point_reco': 'entrance',
#   'outbuildin': 'not surveyed',
#   'comment': 'Structural damage',
#   'eligibilit': 'not Nat.Reg.eligible',
#   'shpo_concu': 'Not Applicable',
#   'collapsed_': '3',
#   'surveyor_n': 'Goodwin and Associates',
#   'photograph': 'Goodwin and Associates',
#   'photo1': 'PC200018.JPG',
#   'photo1path': 'https://gisimage.nola.gov/Section106/58FD1/GC1221/PC200018.JPG',
#   'photo2path': 'https://gisimage.nola.gov/Section106/58FD1/GC1221/',
#   'photo3path': 'https://gisimage.nola.gov/Section106/58FD1/GC1221/',
#   'photo4path': 'https://gisimage.nola.gov/Section106/58FD1/GC1221/',
#   'photofile': 'GC1221',
#   'corr_type': 'Real-time WAAS Corrected',
#   'rcvr_type': 'GeoXM',
#   'gps_date': '2005-12-21T00:00:00.000',
#   'gps_time': '04:28:41pm',
#   'update_sta': 'New',
#   'feat_nam': 'Buildin2',
#   'datafile': 'GC1221F02.SSF',
#   'unfilt_pos': '11',
#   'data_dicti': 'Katrina_Survey_v2',
#   'latitude': '29.972546376',
#   'longitude': '-90.012003722',
#   'prob_zone': 'Moderate',
#   'd_zone': '17 D-10',
#   'd_list': 'no list',
#   'shpo_consu': 'not applicable',
#   'zipcode': '70117',
#   'address': '2201 Caffin Avenue',
#   'demostatus': 'no information provided',
#   'st_num': '2201',
#   'st_name': 'Caffin',
#   'st_suffix': 'Avenue',
#   'location_2': {'type': 'Point',
#    'coordinates': [-90.012003722, 29.972546376]}},
#  {'the_geom': {'type': 'Point',
#    'coordinates': [-90.01229516899997, 29.972653062000063]},
#   'objectid': '15',
#   'gps_id': 'gc00129',
#   'cultural_r': '{4A0E6640-A614-40bb-A117-DC79DC00421D}',
#   'location_i': '{B9A98AAB-0F61-4fac-BFF7-2E25DD94358A}',
#   'survey_id': '{58FD1A36-0E60-41d7-8FDF-EC037D60D827}',
#   'boundary_t': '7',
#   'map_method': '1',
#   'source': 'GPS',
#   'source_dat': '2005-12-21T00:00:00.000',
#   'source_d_1': '3',
#   'source_coo': '1',
#   'source_acc': '+/- 5 meters',
#   'last_updat': '2006-01-25T00:00:00.000',
#   'restrict_s': '1',
#   'street_num': '2206',
#   'street_nam': 'Caffin Avenue',
#   'city_tag': 'red',
#   'city_datab': 'bldg on city list',
#   'constructi': '1940',
#   'date_estim': 'Yes',
#   'less_than_': 'no',
#   'listed_sta': 'Unknown',
#   'contribute': 'No',
#   'significan': 'unknown',
#   'materials_': 'no',
#   'design_int': 'no',
#   'wrkmanship': 'no',
#   'setting_in': 'yes',
#   'location_1': 'no',
#   'foundatio2': 'building off',
#   'wall_condi': 'partial collapse',
#   'roof_condi': 'damaged',
#   'damage_typ': 'multiple',
#   'current_us': 'single dwelling',
#   'style': 'other',
#   'building_t': 'other',
#   'footprint': 'square',
#   'height': '1',
#   'foundation': 'concrete pier',
#   'const_mate': 'frame',
#   'cladding': 'unknown',
#   'roof_mate': 'asphalt shingle',
#   'roof_type': 'other',
#   'chimneys': 'unknown',
#   'porches': 'other',
#   'point_reco': 'center',
#   'outbuildin': 'not surveyed',
#   'comment': 'Severe structure damage',
#   'eligibilit': 'not Nat.Reg.eligible',
#   'shpo_concu': '1',
#   'fema_deter': '2',
#   'shpo_revie': 'Lori Durio, SHPO',
#   'fema_revie': 'Claudia Watson, FEMA',
#   'concur_dat': '2006-04-13T00:00:00.000',
#   'review_com': 'Lack of Significance',
#   'collapsed_': '4',
#   'surveyor_n': 'Goodwin and Associates',
#   'photograph': 'Goodwin and Associates',
#   'photo1': 'PC200019.JPG',
#   'photo1path': 'https://gisimage.nola.gov/Section106/58FD1/GC1221/PC200019.JPG',
#   'photo2path': 'https://gisimage.nola.gov/Section106/58FD1/GC1221/',
#   'photo3path': 'https://gisimage.nola.gov/Section106/58FD1/GC1221/',
#   'photo4path': 'https://gisimage.nola.gov/Section106/58FD1/GC1221/',
#   'photofile': 'GC1221',
#   'corr_type': 'Real-time WAAS Corrected',
#   'rcvr_type': 'GeoXM',
#   'gps_date': '2005-12-21T00:00:00.000',
#   'gps_time': '04:41:24pm',
#   'update_sta': 'New',
#   'feat_nam': 'Buildin2',
#   'datafile': 'GC1221F02.SSF',
#   'unfilt_pos': '21',
#   'data_dicti': 'Katrina_Survey_v2',
#   'latitude': '29.972652691',
#   'longitude': '-90.012295118',
#   'prob_zone': 'Moderate',
#   'd_zone': '17 D-10',
#   'd_list': 'C',
#   'shpo_consu': '6/22/2006',
#   'arch_tier': 'T0',
#   'zipcode': '70117',
#   'address': '2206 Caffin Avenue',
#   'demostatus': 'USACE 8/14/2006',
#   'st_num': '2206',
#   'st_name': 'Caffin',
#   'st_suffix': 'Avenue',
#   'location_2': {'type': 'Point',
#    'coordinates': [-90.012295118, 29.972652691]}},
#  {'the_geom': {'type': 'Point',
#    'coordinates': [-90.01225316899996, 29.97279306200005]},
#   'objectid': '16',
#   'gps_id': 'gc00130',
#   'cultural_r': '{C899464A-1E75-44f9-B27D-554E2C0B0DA3}',
#   'location_i': '{CF11D10D-6323-4166-9257-17AB481F8FA5}',
#   'survey_id': '{58FD1A36-0E60-41d7-8FDF-EC037D60D827}',
#   'boundary_t': '8',
#   'map_method': '1',
#   'source': 'GPS',
#   'source_dat': '2005-12-21T00:00:00.000',
#   'source_d_1': '3',
#   'source_coo': '1',
#   'source_acc': '+/- 5 meters',
#   'last_updat': '2006-01-25T00:00:00.000',
#   'restrict_s': '1',
#   'street_num': '2210',
#   'street_nam': 'Caffin Avenue',
#   'city_tag': 'red',
#   'city_datab': 'bldg on city list',
#   'constructi': '1940',
#   'date_estim': 'Yes',
#   'less_than_': 'no',
#   'listed_sta': 'multiple',
#   'contribute': 'No',
#   'significan': 'unknown',
#   'materials_': 'no',
#   'design_int': 'no',
#   'wrkmanship': 'no',
#   'setting_in': 'yes',
#   'location_1': 'no',
#   'foundatio2': 'building off',
#   'wall_condi': 'partial collapse',
#   'roof_condi': 'damaged',
#   'damage_typ': 'multiple',
#   'current_us': 'single dwelling',
#   'style': 'other',
#   'building_t': 'other',
#   'footprint': 'rectangular',
#   'height': '1',
#   'foundation': 'concrete pier',
#   'const_mate': 'frame',
#   'cladding': 'unknown',
#   'roof_mate': 'asphalt shingle',
#   'roof_type': 'hip',
#   'chimneys': 'unknown',
#   'porches': 'none',
#   'point_reco': 'southeast corner',
#   'outbuildin': 'not surveyed',
#   'comment': 'Off lot',
#   'eligibilit': 'not Nat.Reg.eligible',
#   'shpo_concu': '1',
#   'fema_deter': '2',
#   'shpo_revie': 'Lori Durio, SHPO',
#   'fema_revie': 'Claudia Watson, FEMA',
#   'concur_dat': '2006-04-13T00:00:00.000',
#   'review_com': 'Lack of Significance',
#   'collapsed_': '4',
#   'surveyor_n': 'Goodwin and Associates',
#   'photograph': 'Goodwin and Associates',
#   'photo1': 'PC200020.JPG',
#   'photo1path': 'https://gisimage.nola.gov/Section106/58FD1/GC1221/PC200020.JPG',
#   'photo2path': 'https://gisimage.nola.gov/Section106/58FD1/GC1221/',
#   'photo3path': 'https://gisimage.nola.gov/Section106/58FD1/GC1221/',
#   'photo4path': 'https://gisimage.nola.gov/Section106/58FD1/GC1221/',
#   'photofile': 'GC1221',
#   'corr_type': 'Real-time WAAS Corrected',
#   'rcvr_type': 'GeoXM',
#   'gps_date': '2005-12-21T00:00:00.000',
#   'gps_time': '04:45:57pm',
#   'update_sta': 'New',
#   'feat_nam': 'Buildin2',
#   'datafile': 'GC1221F02.SSF',
#   'unfilt_pos': '14',
#   'data_dicti': 'Katrina_Survey_v2',
#   'latitude': '29.972792718',
#   'longitude': '-90.012252997',
#   'prob_zone': 'Moderate',
#   'd_zone': '17 D-10',
#   'd_list': 'C',
#   'shpo_consu': '6/22/2006',
#   'arch_tier': 'T0',
#   'zipcode': '70117',
#   'address': '2210 Caffin Avenue',
#   'demostatus': 'USACE 8/14/2006',
#   'st_num': '2210',
#   'st_name': 'Caffin',
#   'st_suffix': 'Avenue',
#   'location_2': {'type': 'Point',
#    'coordinates': [-90.012252997, 29.972792718]}},
#  {'the_geom': {'type': 'Point',
#    'coordinates': [-90.01177416899998, 29.972882062000053]},
#   'objectid': '17',
#   'gps_id': 'gc00131',
#   'cultural_r': '{192A478A-2E56-4ccd-BFB0-EC9D86D7F3CD}',
#   'location_i': '{AD2E6C75-B3FC-47a3-9A7F-16555789172D}',
#   'survey_id': '{58FD1A36-0E60-41d7-8FDF-EC037D60D827}',
#   'boundary_t': '7',
#   'map_method': '1',
#   'source': 'GPS',
#   'source_dat': '2005-12-21T00:00:00.000',
#   'source_d_1': '3',
#   'source_coo': '1',
#   'source_acc': '+/- 5 meters',
#   'last_updat': '2006-01-25T00:00:00.000',
#   'restrict_s': '1',
#   'street_num': '2219',
#   'street_nam': 'Caffin Avenue',
#   'city_tag': 'red',
#   'city_datab': 'bldg not on city list',
#   'constructi': '1950',
#   'date_estim': 'Yes',
#   'less_than_': 'no',
#   'listed_sta': 'Unknown',
#   'contribute': 'No',
#   'significan': 'unknown',
#   'materials_': 'yes',
#   'design_int': 'yes',
#   'wrkmanship': 'yes',
#   'setting_in': 'yes',
#   'location_1': 'yes',
#   'foundatio2': 'unknown',
#   'wall_condi': 'unknown',
#   'roof_condi': 'damaged',
#   'damage_typ': 'unknown',
#   'current_us': 'multiple dwelling',
#   'style': 'other',
#   'building_t': 'other',
#   'footprint': 'square',
#   'height': '2',
#   'foundation': 'continuous concrete',
#   'const_mate': 'concrete block',
#   'cladding': 'unknown',
#   'roof_mate': 'asphalt shingle',
#   'roof_type': 'hip',
#   'chimneys': 'unknown',
#   'porches': 'other',
#   'point_reco': 'center',
#   'outbuildin': 'not surveyed',
#   'comment': 'Nondescript apartments',
#   'eligibilit': 'not Nat.Reg.eligible',
#   'shpo_concu': 'Not Applicable',
#   'collapsed_': '3',
#   'surveyor_n': 'Goodwin and Associates',
#   'photograph': 'Goodwin and Associates',
#   'photo1': 'PC200021.JPG',
#   'photo1path': 'https://gisimage.nola.gov/Section106/58FD1/GC1221/PC200021.JPG',
#   'photo2path': 'https://gisimage.nola.gov/Section106/58FD1/GC1221/',
#   'photo3path': 'https://gisimage.nola.gov/Section106/58FD1/GC1221/',
#   'photo4path': 'https://gisimage.nola.gov/Section106/58FD1/GC1221/',
#   'photofile': 'GC1221',
#   'corr_type': 'Real-time WAAS Corrected',
#   'rcvr_type': 'GeoXM',
#   'gps_date': '2005-12-21T00:00:00.000',
#   'gps_time': '04:53:00pm',
#   'update_sta': 'New',
#   'feat_nam': 'Buildin2',
#   'datafile': 'GC1221F02.SSF',
#   'unfilt_pos': '11',
#   'data_dicti': 'Katrina_Survey_v2',
#   'latitude': '29.972881622',
#   'longitude': '-90.011774520',
#   'prob_zone': 'Moderate',
#   'd_zone': '17 D-10',
#   'd_list': 'no list',
#   'shpo_consu': 'not applicable',
#   'zipcode': '70117',
#   'address': '2219 Caffin Avenue',
#   'demostatus': 'no information provided',
#   'st_num': '2219',
#   'st_name': 'Caffin',
#   'st_suffix': 'Avenue',
#   'location_2': {'type': 'Point',
#    'coordinates': [-90.01177452, 29.972881622]}},
#  {'the_geom': {'type': 'Point',
#    'coordinates': [-90.00979216899998, 29.975529062000078]},
# ...
#   'roof_type': 'unknown',
#   'chimneys': 'unknown',
#   'chimney_ma': 'unknown',
#   'porches': 'full width',
#   'point_reco': 'entrance',
#   'outbuildin': 'not surveyed',
#   'eligibilit': 'not Nat.Reg.eligible',
#   'shpo_concu': '1',
#   'fema_deter': '2',
#   'shpo_revie': 'Lori Durio, SHPO',
#   'fema_revie': 'Claudia Watson, FEMA',
#   'concur_dat': '2006-03-24T00:00:00.000',
#   'collapsed_': '1',
#   'surveyor_n': 'Tish Rankin',
#   'photograph': 'Tish Rankin',
#   'photo1': 'IMGP0258.JPG',
#   'photo2': 'IMGP0259.JPG',
#   'photo1path': 'https://gisimage.nola.gov/Section106/58FD1/CC0203/IMGP0258.JPG',
#   'photo2path': 'https://gisimage.nola.gov/Section106/58FD1/CC0203/IMGP0259.JPG',
#   'photo3path': 'https://gisimage.nola.gov/Section106/58FD1/CC0203/',
#   'photo4path': 'https://gisimage.nola.gov/Section106/58FD1/CC0203/',
#   'photofile': 'CC0203',
#   'corr_type': 'Uncorrected',
#   'rcvr_type': 'GeoXT',
#   'gps_date': '2006-02-03T00:00:00.000',
#   'gps_time': '01:17:16pm',
#   'update_sta': 'New',
#   'feat_nam': 'Buildin2',
#   'datafile': 'CC0203F01.SSF',
#   'unfilt_pos': '11',
#   'data_dicti': 'Katrina_Survey_v3',
#   'latitude': '29.975555439',
#   'longitude': '-90.018480917',
#   'prob_zone': 'Moderate',
#   'd_zone': '17 C-2',
#   'd_list': 'C',
#   'shpo_consu': '5/25/2006',
#   'arch_tier': 'T0',
#   'zipcode': '70117',
#   'address': '2307 Tennessee Street',
#   'demostatus': 'no information provided',
#   'st_num': '2307',
#   'st_name': 'Tennessee',
#   'st_suffix': 'Street',
#   'location_2': {'type': 'Point',
#    'coordinates': [-90.018480917, 29.975555439]}},
#  {'the_geom': {'type': 'Point',
#    'coordinates': [-90.01300816899999, 29.978077062000068]},
#   'objectid': '996',
#   'gps_id': 'ca00439',
#   'cultural_r': '{609DB780-C13E-4ffc-AAB4-3449970508D2}',
#   'location_i': '{CE139914-3CC6-4cba-8C00-460D320DFC66}',
#   'survey_id': '{58FD1A36-0E60-41d7-8FDF-EC037D60D827}',
#   'boundary_t': '6',
#   'map_method': '1',
#   'source': 'GPS',
#   'source_dat': '2006-02-07T00:00:00.000',
#   'source_d_1': '3',
#   'source_coo': '1',
#   'source_acc': '+/- 5 meters',
#   'last_updat': '2006-02-08T00:00:00.000',
#   'restrict_s': '1',
#   'street_num': '5400',
#   'street_nam': 'Florida Avenue',
#   'city_tag': 'none',
#   'city_datab': 'bldg on city list',
#   'constructi': '1950-65',
#   'date_estim': 'Yes',
#   'less_than_': 'unsure',
#   'listed_sta': 'none',
#   'contribute': 'No',
#   'significan': 'not significant',
#   'historic_c': 'most bldgs on block destroyed',
#   'materials_': 'no',
#   'design_int': 'no',
#   'wrkmanship': 'no',
#   'setting_in': 'no',
#   'location_1': 'yes',
#   'foundatio2': 'intact',
#   'wall_condi': 'total collapse',
#   'roof_condi': 'total collapse',
#   'damage_typ': 'multiple',
#   'current_us': 'unknown',
#   'style': 'unknown',
#   'building_t': 'ranch',
#   'footprint': 'rectangular',
#   'height': '1',
#   'foundation': 'concrete slab',
#   'const_mate': 'frame',
#   'cladding': 'masonry',
#   'roof_mate': 'asphalt shingle',
#   'roof_type': 'unknown',
#   'chimneys': 'unknown',
#   'chimney_ma': 'unknown',
#   'porches': 'unknown',
#   'point_reco': 'entrance',
#   'outbuildin': 'not surveyed',
#   'eligibilit': 'not Nat.Reg.eligible',
#   'shpo_concu': '1',
#   'fema_deter': '2',
#   'shpo_revie': 'Lori Durio, SHPO',
#   'fema_revie': 'Claudia Watson, FEMA',
#   'concur_dat': '2006-03-24T00:00:00.000',
#   'collapsed_': '1',
#   'surveyor_n': 'Sara Hahn',
#   'photograph': 'Thurston Hahn',
#   'photo1': 'DSCN1359.JPG',
#   'photo2': 'DSCN1360.JPG',
#   'photo1path': 'https://gisimage.nola.gov/Section106/58FD1/CA0207/DSCN1359.JPG',
#   'photo2path': 'https://gisimage.nola.gov/Section106/58FD1/CA0207/DSCN1360.JPG',
#   'photo3path': 'https://gisimage.nola.gov/Section106/58FD1/CA0207/',
#   'photo4path': 'https://gisimage.nola.gov/Section106/58FD1/CA0207/',
#   'photofile': 'CA0207',
#   'corr_type': 'Real-time WAAS Corrected',
#   'rcvr_type': 'GeoXT',
#   'gps_date': '2006-02-07T00:00:00.000',
#   'gps_time': '10:53:27am',
#   'update_sta': 'New',
#   'feat_nam': 'Buildin2',
#   'datafile': 'CA0207F01.SSF',
#   'unfilt_pos': '11',
#   'data_dicti': 'Katrina_Survey_v3',
#   'latitude': '29.978076679',
#   'longitude': '-90.013007849',
#   'prob_zone': 'Low',
#   'd_zone': '17 D-1',
#   'd_list': 'C',
#   'shpo_consu': '5/25/2006',
#   'arch_tier': 'T0',
#   'zipcode': '70117',
#   'address': '5400 Florida Avenue',
#   'demostatus': 'no information provided',
#   'st_num': '5400',
#   'st_name': 'Florida',
#   'st_suffix': 'Avenue',
#   'location_2': {'type': 'Point',
#    'coordinates': [-90.013007849, 29.978076679]}},
#  {'the_geom': {'type': 'Point',
#    'coordinates': [-90.01310716899997, 29.977685062000035]},
#   'objectid': '997',
#   'gps_id': 'ca00440',
#   'cultural_r': '{F69FFD3C-6EE2-49af-99ED-FE558CB7C2D6}',
#   'location_i': '{92455397-B483-485b-A8F6-D41EBFB3D78D}',
#   'survey_id': '{58FD1A36-0E60-41d7-8FDF-EC037D60D827}',
#   'boundary_t': '8',
#   'map_method': '1',
#   'source': 'GPS',
#   'source_dat': '2006-02-07T00:00:00.000',
#   'source_d_1': '3',
#   'source_coo': '1',
#   'source_acc': '+/- 5 meters',
#   'last_updat': '2006-02-08T00:00:00.000',
#   'restrict_s': '1',
#   'street_num': '2625-25.5',
#   'street_nam': 'Andry Street',
#   'city_tag': 'none',
#   'city_datab': 'bldg on city list',
#   'constructi': '1950-65',
#   'date_estim': 'Yes',
#   'less_than_': 'unsure',
#   'listed_sta': 'none',
#   'contribute': 'No',
#   'significan': 'not significant',
#   'historic_c': 'most bldgs on block destroyed',
#   'materials_': 'no',
#   'design_int': 'no',
#   'wrkmanship': 'no',
#   'setting_in': 'no',
#   'location_1': 'yes',
#   'foundatio2': 'intact',
#   'wall_condi': 'racked',
#   'roof_condi': 'damaged',
#   'damage_typ': 'multiple',
#   'current_us': 'multiple dwelling',
#   'style': 'unknown',
#   'building_t': 'minimal traditional',
#   'footprint': 'rectangular',
#   'height': '1',
#   'foundation': 'concrete slab',
#   'const_mate': 'frame',
#   'cladding': 'masonry',
#   'roof_mate': 'asphalt shingle',
#   'roof_type': 'front gable',
#   'chimneys': 'unknown',
#   'chimney_ma': 'unknown',
#   'porches': 'none',
#   'point_reco': 'northwest corner',
#   'outbuildin': 'not surveyed',
#   'eligibilit': 'not Nat.Reg.eligible',
#   'shpo_concu': '1',
#   'fema_deter': '2',
#   'shpo_revie': 'Lori Durio, SHPO',
#   'fema_revie': 'Claudia Watson, FEMA',
#   'concur_dat': '2006-04-13T00:00:00.000',
#   'review_com': 'Lack of Significance',
#   'collapsed_': '4',
#   'surveyor_n': 'Sara Hahn',
#   'photograph': 'Thurston Hahn',
#   'photo1': 'DSCN1361.JPG',
#   'photo2': 'DSCN1362.JPG',
#   'photo1path': 'https://gisimage.nola.gov/Section106/58FD1/CA0207/DSCN1361.JPG',
#   'photo2path': 'https://gisimage.nola.gov/Section106/58FD1/CA0207/DSCN1362.JPG',
#   'photo3path': 'https://gisimage.nola.gov/Section106/58FD1/CA0207/',
#   'photo4path': 'https://gisimage.nola.gov/Section106/58FD1/CA0207/',
#   'photofile': 'CA0207',
#   'corr_type': 'Uncorrected',
#   'rcvr_type': 'GeoXT',
#   'gps_date': '2006-02-07T00:00:00.000',
#   'gps_time': '11:05:05am',
#   'update_sta': 'New',
#   'feat_nam': 'Buildin2',
#   'datafile': 'CA0207F01.SSF',
#   'unfilt_pos': '11',
#   'data_dicti': 'Katrina_Survey_v3',
#   'latitude': '29.977684823',
#   'longitude': '-90.013106678',
#   'prob_zone': 'Moderate',
#   'd_zone': '17 D-1',
#   'd_list': 'C',
#   'shpo_consu': '6/22/2006',
#   'arch_tier': 'T0',
#   'zipcode': '70117',
#   'address': '2625-25.5 Andry Street',
#   'demostatus': 'USACE 8/5/2006',
#   'st_num': '2625-25.5',
#   'st_name': 'Andry',
#   'st_suffix': 'Street',
#   'location_2': {'type': 'Point',
#    'coordinates': [-90.013106678, 29.977684823]}},
#  {'the_geom': {'type': 'Point',
#    'coordinates': [-90.01311816899994, 29.977505062000034]},
#   'objectid': '998',
#   'gps_id': 'ca00441',
#   'cultural_r': '{6E339D44-962C-495b-890C-401C7241E0AA}',
#   'location_i': '{08C3CA8B-7A30-4402-852D-1B4072977274}',
#   'survey_id': '{58FD1A36-0E60-41d7-8FDF-EC037D60D827}',
#   'boundary_t': '7',
#   'map_method': '1',
#   'source': 'GPS',
#   'source_dat': '2006-02-07T00:00:00.000',
#   'source_d_1': '3',
#   'source_coo': '1',
#   'source_acc': '+/- 5 meters',
#   'last_updat': '2006-02-08T00:00:00.000',
#   'restrict_s': '1',
#   'street_num': '2611-13',
#   'street_nam': 'Andry Street',
#   'city_tag': 'none',
#   'city_datab': 'bldg on city list',
#   'constructi': '1960',
#   'date_estim': 'Yes',
#   'less_than_': 'yes',
#   'listed_sta': 'none',
#   'contribute': 'No',
#   'significan': 'not significant',
#   'historic_c': 'most bldgs on block destroyed',
#   'materials_': 'no',
#   'design_int': 'no',
#   'wrkmanship': 'no',
#   'setting_in': 'no',
#   'location_1': 'yes',
#   'foundatio2': 'building off',
#   'wall_condi': 'racked',
#   'roof_condi': 'damaged',
#   'damage_typ': 'multiple',
#   'current_us': 'multiple dwelling',
#   'style': 'unknown',
#   'building_t': 'other',
#   'footprint': 'rectangular',
#   'height': '2',
#   'foundation': 'concrete block',
#   'const_mate': 'frame',
#   'cladding': 'vinyl',
#   'roof_mate': 'asphalt shingle',
#   'roof_type': 'hip',
#   'chimneys': 'unknown',
#   'chimney_ma': 'unknown',
#   'porches': 'full width',
#   'point_reco': 'center',
#   'outbuildin': 'not surveyed',
#   'eligibilit': 'not Nat.Reg.eligible',
#   'shpo_concu': '1',
#   'fema_deter': '2',
#   'shpo_revie': 'Lori Durio, SHPO',
#   'fema_revie': 'Claudia Watson, FEMA',
#   'concur_dat': '2006-04-13T00:00:00.000',
#   'review_com': 'Lack of Significance',
#   'collapsed_': '4',
#   'surveyor_n': 'Sara Hahn',
#   'photograph': 'Thurston Hahn',
#   'photo1': 'DSCN1363.JPG',
#   'photo2': 'DSCN1364.JPG',
#   'photo3': 'DSCN1365.JPG',
#   'photo1path': 'https://gisimage.nola.gov/Section106/58FD1/CA0207/DSCN1363.JPG',
#   'photo2path': 'https://gisimage.nola.gov/Section106/58FD1/CA0207/DSCN1364.JPG',
#   'photo3path': 'https://gisimage.nola.gov/Section106/58FD1/CA0207/DSCN1365.JPG',
#   'photo4path': 'https://gisimage.nola.gov/Section106/58FD1/CA0207/',
#   'photofile': 'CA0207',
#   'corr_type': 'Uncorrected',
#   'rcvr_type': 'GeoXT',
#   'gps_date': '2006-02-07T00:00:00.000',
#   'gps_time': '11:08:11am',
#   'update_sta': 'New',
#   'feat_nam': 'Buildin2',
#   'datafile': 'CA0207F01.SSF',
#   'unfilt_pos': '10',
#   'data_dicti': 'Katrina_Survey_v3',
#   'latitude': '29.977504962',
#   'longitude': '-90.013118469',
#   'prob_zone': 'Moderate',
#   'd_zone': '17 D-1',
#   'd_list': 'C',
#   'shpo_consu': '6/22/2006',
#   'arch_tier': 'T0',
#   'zipcode': '70117',
#   'address': '2611-13 Andry Street',
#   'demostatus': 'USACE 8/14/2006',
#   'st_num': '2611-13',
#   'st_name': 'Andry',
#   'st_suffix': 'Street',
#   'location_2': {'type': 'Point',
#    'coordinates': [-90.013118469, 29.977504962]}},
#  {'the_geom': {'type': 'Point',
#    'coordinates': [-90.01352916899998, 29.97725506200004]},
#   'objectid': '999',
#   'gps_id': 'ca00442',
#   'cultural_r': '{B3FB312F-B2D3-46d7-BE96-D055183B3DC4}',
#   'location_i': '{3F46B0A5-8941-4078-9CC2-67A3056ADCAB}',
#   'survey_id': '{58FD1A36-0E60-41d7-8FDF-EC037D60D827}',
#   'boundary_t': '8',
#   'map_method': '1',
#   'source': 'GPS',
#   'source_dat': '2006-02-07T00:00:00.000',
#   'source_d_1': '3',
#   'source_coo': '1',
#   'source_acc': '+/- 5 meters',
#   'last_updat': '2006-02-08T00:00:00.000',
#   'restrict_s': '1',
#   'street_num': '2600',
#   'street_nam': 'Andry Street',
#   'city_tag': 'none',
#   'city_datab': 'bldg not on city list',
#   'constructi': '1960',
#   'date_estim': 'Yes',
#   'less_than_': 'yes',
#   'listed_sta': 'none',
#   'contribute': 'No',
#   'significan': 'not significant',
#   'historic_c': 'most bldgs on block destroyed',
#   'materials_': 'no',
#   'design_int': 'no',
#   'wrkmanship': 'no',
#   'setting_in': 'no',
#   'location_1': 'no',
#   'foundatio2': 'building off',
#   'wall_condi': 'racked',
#   'roof_condi': 'damaged',
#   'damage_typ': 'multiple',
#   'current_us': 'single dwelling',
#   'style': '20th Cen. Revival',
#   'building_t': 'bungalow',
#   'footprint': 'rectangular',
#   'height': '1',
#   'foundation': 'concrete block',
#   'const_mate': 'frame',
#   'cladding': 'other',
#   'roof_mate': 'asphalt shingle',
#   'roof_type': 'hip',
#   'chimneys': 'unknown',
#   'chimney_ma': 'unknown',
#   'porches': 'partial width',
#   'point_reco': 'southeast corner',
#   'outbuildin': 'not surveyed',
#   'eligibilit': 'not Nat.Reg.eligible',
#   'shpo_concu': 'Not Applicable',
#   'collapsed_': '3',
#   'surveyor_n': 'Sara Hahn',
#   'photograph': 'Thurston Hahn',
#   'photo1': 'DSCN1366.JPG',
#   'photo2': 'DSCN1367.JPG',
#   'photo3': 'DSCN1368.JPG',
#   'photo1path': 'https://gisimage.nola.gov/Section106/58FD1/CA0207/DSCN1366.JPG',
#   'photo2path': 'https://gisimage.nola.gov/Section106/58FD1/CA0207/DSCN1367.JPG',
#   'photo3path': 'https://gisimage.nola.gov/Section106/58FD1/CA0207/DSCN1368.JPG',
#   'photo4path': 'https://gisimage.nola.gov/Section106/58FD1/CA0207/',
#   'photofile': 'CA0207',
#   'corr_type': 'Real-time WAAS Corrected',
#   'rcvr_type': 'GeoXT',
#   'gps_date': '2006-02-07T00:00:00.000',
#   'gps_time': '11:16:54am',
#   'update_sta': 'New',
#   'feat_nam': 'Buildin2',
#   'datafile': 'CA0207F01.SSF',
#   'unfilt_pos': '11',
#   'data_dicti': 'Katrina_Survey_v3',
#   'latitude': '29.977254839',
#   'longitude': '-90.013529638',
#   'prob_zone': 'Moderate',
#   'd_zone': '17 D-1',
#   'd_list': 'no list',
#   'shpo_consu': 'not applicable',
#   'zipcode': '70117',
#   'address': '2600 Andry Street',
#   'demostatus': 'no information provided',
#   'st_num': '2600',
#   'st_name': 'Andry',
#   'st_suffix': 'Street',
#   'location_2': {'type': 'Point',
#    'coordinates': [-90.013529638, 29.977254839]}},
#  {'the_geom': {'type': 'Point',
#    'coordinates': [-90.01300616899994, 29.97635406200004]},
#   'objectid': '1000',
#   'gps_id': 'ca00449',
#   'cultural_r': '{3BFAA7ED-8BC4-4a13-AAD0-4A86EB3B283E}',
#   'location_i': '{954B444F-20EE-49d4-80B2-C00EC06FF94F}',
#   'survey_id': '{58FD1A36-0E60-41d7-8FDF-EC037D60D827}',
#   'boundary_t': '6',
#   'map_method': '1',
#   'source': 'GPS',
#   'source_dat': '2006-02-07T00:00:00.000',
#   'source_d_1': '3',
#   'source_coo': '1',
#   'source_acc': '+/- 5 meters',
#   'last_updat': '2006-02-08T00:00:00.000',
#   'restrict_s': '1',
#   'street_num': '2530',
#   'street_nam': 'Choctaw Street',
#   'city_tag': 'none',
#   'city_datab': 'bldg on city list',
#   'constructi': '1910-30',
#   'date_estim': 'Yes',
#   'less_than_': 'no',
#   'listed_sta': 'none',
#   'contribute': 'No',
#   'significan': 'not significant',
#   'historic_c': 'most bldgs on block destroyed',
#   'materials_': 'no',
#   'design_int': 'no',
#   'wrkmanship': 'no',
#   'setting_in': 'no',
#   'location_1': 'no',
#   'foundatio2': 'building off',
#   'wall_condi': 'racked',
#   'roof_condi': 'damaged',
#   'damage_typ': 'multiple',
#   'current_us': 'single dwelling',
#   'style': 'unknown',
#   'building_t': 'shotgun',
#   'footprint': 'L-shaped',
#   'height': '1',
#   'foundation': 'concrete block',
#   'const_mate': 'frame',
#   'cladding': 'wood',
#   'roof_mate': 'asphalt shingle',
#   'roof_type': 'front gable',
#   'chimneys': 'unknown',
#   'chimney_ma': 'unknown',
#   'porches': 'unknown',
#   'point_reco': 'entrance',
#   'outbuildin': 'not surveyed',
#   'eligibilit': 'not Nat.Reg.eligible',
#   'shpo_concu': '1',
#   'fema_deter': '2',
#   'shpo_revie': 'Lori Durio, SHPO',
#   'fema_revie': 'Claudia Watson, FEMA',
#   'concur_dat': '2006-04-17T00:00:00.000',
#   'review_com': 'Lack of Significance',
#   'collapsed_': '4',
#   'surveyor_n': 'Sara Hahn',
#   'photograph': 'Thurston Hahn',
#   'photo1': 'DSCN1383.JPG',
#   'photo2': 'DSCN1384.JPG',
#   'photo1path': 'https://gisimage.nola.gov/Section106/58FD1/CA0207/DSCN1383.JPG',
#   'photo2path': 'https://gisimage.nola.gov/Section106/58FD1/CA0207/DSCN1384.JPG',
#   'photo3path': 'https://gisimage.nola.gov/Section106/58FD1/CA0207/',
#   'photo4path': 'https://gisimage.nola.gov/Section106/58FD1/CA0207/',
#   'photofile': 'CA0207',
#   'corr_type': 'Uncorrected',
#   'rcvr_type': 'GeoXT',
#   'gps_date': '2006-02-07T00:00:00.000',
#   'gps_time': '12:05:08pm',
#   'update_sta': 'New',
#   'feat_nam': 'Buildin2',
#   'datafile': 'CA0207F01.SSF',
#   'unfilt_pos': '11',
#   'data_dicti': 'Katrina_Survey_v3',
#   'latitude': '29.976353993',
#   'longitude': '-90.013006311',
#   'prob_zone': 'Moderate',
#   'd_zone': '17 D-1',
#   'd_list': 'C',
#   'shpo_consu': '6/22/2006',
#   'arch_tier': 'T0',
#   'zipcode': '70117',
#   'address': '2530 Choctaw Street',
#   'demostatus': 'USACE 7/31/2006',
#   'st_num': '2530',
#   'st_name': 'Choctaw',
#   'st_suffix': 'Street',
#   'location_2': {'type': 'Point',
#    'coordinates': [-90.013006311, 29.976353993]}}]

# %%
nola_metadata = nola_client.get_metadata(nola_dataset_identifier)
nola_metadata
# Out:
# {'id': 'fcuq-eeca',
#  'name': 'Katrina 2005 FEMA Demolition Requests',
#  'assetType': 'dataset',
#  'attribution': 'City of New Orleans',
#  'averageRating': 0,
#  'category': 'Housing, Land Use, and Blight',
#  'createdAt': 1756829815,
#  'description': 'Properties submitted for demolition following Hurricane Katrina as part of the requirements of Section 106 of the Historic Preservation Act.',
#  'diciBackend': False,
#  'displayType': 'table',
#  'downloadCount': 318,
#  'hideFromCatalog': False,
#  'hideFromDataJson': False,
#  'licenseId': 'CC0_10',
#  'locked': False,
#  'newBackend': True,
#  'numberOfComments': 0,
#  'oid': 41558439,
#  'provenance': 'official',
#  'publicationAppendEnabled': False,
#  'publicationDate': 1756833883,
#  'publicationGroup': 20038209,
#  'publicationStage': 'published',
#  'rowsUpdatedAt': 1756833835,
#  'rowsUpdatedBy': 'wvd3-542u',
#  'tableId': 20038209,
#  'totalTimesRated': 0,
#  'viewCount': 306,
#  'viewLastModified': 1756833883,
#  'viewType': 'tabular',
#  'approvals': [{'reviewedAt': 1756833883,
#    'reviewedAutomatically': True,
#    'state': 'approved',
#    'submissionId': 7059153,
#    'submissionObject': 'public_audience_request',
#    'submissionOutcome': 'change_audience',
#    'submittedAt': 1756833883,
#    'targetAudience': 'public',
#    'workflowId': 2032,
#    'submissionDetails': {'permissionType': 'READ'},
#    'submissionOutcomeApplication': {'endedAt': 1756833883,
#     'failureCount': 0,
#     'startedAt': 1756833883,
#     'status': 'success'},
#    'submitter': {'id': 'wvd3-542u', 'displayName': 'Christopher Ard'}}],
#  'clientContext': {'clientContextVariables': [], 'inheritedVariables': {}},
#  'columns': [{'id': 616490707,
#    'name': 'the_geom',
#    'dataTypeName': 'point',
#    'description': '',
#    'fieldName': 'the_geom',
#    'position': 1,
#    'renderTypeName': 'point',
#    'tableColumnId': 161165370,
#    'cachedContents': {'non_null': '9334',
#     'null': '0',
#     'top': [{'item': {'coordinates': [-90.09069509699998, 29.94381252900007],
#        'type': 'Point'},
#       'count': '1'},
#      {'item': {'coordinates': [-90.10157116899995, 30.01567506200007],
#        'type': 'Point'},
#       'count': '1'},
#      {'item': {'coordinates': [-90.01816716899998, 29.978082062000055],
#        'type': 'Point'},
#       'count': '1'},
#      {'item': {'coordinates': [-90.04067391299998, 29.99630639800006],
#        'type': 'Point'},
#       'count': '1'},
#      {'item': {'coordinates': [-90.03854616899997, 30.00743506200007],
#        'type': 'Point'},
#       'count': '1'},
#      {'item': {'coordinates': [-90.09424916899997, 29.918707062000067],
#        'type': 'Point'},
#       'count': '1'},
#      {'item': {'coordinates': [-90.09875416899996, 29.96892106200005],
#        'type': 'Point'},
#       'count': '1'},
#      {'item': {'coordinates': [-90.10162016899994, 29.941421062000074],
#        'type': 'Point'},
#       'count': '1'},
#      {'item': {'coordinates': [-90.00787816899998, 29.967509062000033],
#        'type': 'Point'},
#       'count': '1'},
#      {'item': {'coordinates': [-90.03945792699994, 30.013234347000036],
#        'type': 'Point'},
#       'count': '1'},
#      {'item': {'coordinates': [-90.03334716899997, 30.015541062000068],
#        'type': 'Point'},
#       'count': '1'},
#      {'item': {'coordinates': [-89.96568024899994, 30.025476269000023],
#        'type': 'Point'},
#       'count': '1'},
#      {'item': {'coordinates': [-90.03638716899997, 29.989879062000057],
#        'type': 'Point'},
#       'count': '1'},
#      {'item': {'coordinates': [-90.04098172199997, 29.983440861000076],
#        'type': 'Point'},
#       'count': '1'},
#      {'item': {'coordinates': [-90.01138616899999, 29.969107062000035],
#        'type': 'Point'},
#       'count': '1'},
#      {'item': {'coordinates': [-90.11007416899997, 30.01633606200005],
#        'type': 'Point'},
#       'count': '1'},
#      {'item': {'coordinates': [-90.01837484099997, 29.96574925500005],
#        'type': 'Point'},
#       'count': '1'},
#      {'item': {'coordinates': [-90.00235216899995, 29.97074106200006],
#        'type': 'Point'},
#       'count': '1'},
#      {'item': {'coordinates': [-90.00046216899995, 29.971361062000028],
#        'type': 'Point'},
#       'count': '1'},
#      {'item': {'coordinates': [-90.08771016899999, 29.971267062000038],
#        'type': 'Point'},
#       'count': '1'}],
#     'count': '9334',
#     'cardinality': '9334'},
#    'format': {}},
#   {'id': 616490639,
#    'name': 'OBJECTID',
#    'dataTypeName': 'number',
#    'description': '',
#    'fieldName': 'objectid',
#    'position': 2,
#    'renderTypeName': 'number',
#    'tableColumnId': 161165302,
#    'cachedContents': {'non_null': '9334',
#     'largest': '9334',
#     'null': '0',
#     'top': [{'item': '4773', 'count': '1'},
#      {'item': '2747', 'count': '1'},
#      {'item': '2482', 'count': '1'},
#      {'item': '8657', 'count': '1'},
#      {'item': '4042', 'count': '1'},
#      {'item': '1893', 'count': '1'},
#      {'item': '3635', 'count': '1'},
#      {'item': '37', 'count': '1'},
#      {'item': '3446', 'count': '1'},
#      {'item': '7767', 'count': '1'},
#      {'item': '7360', 'count': '1'},
#      {'item': '6061', 'count': '1'},
#      {'item': '4392', 'count': '1'},
#      {'item': '5912', 'count': '1'},
#      {'item': '8479', 'count': '1'},
#      {'item': '8905', 'count': '1'},
#      {'item': '2087', 'count': '1'},
#      {'item': '6406', 'count': '1'},
#      {'item': '5324', 'count': '1'},
#      {'item': '5599', 'count': '1'}],
#     'smallest': '1',
#     'count': '9334',
#     'cardinality': '9334'},
#    'format': {}},
#   {'id': 616490644,
#    'name': 'GPS_ID',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'gps_id',
#    'position': 3,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165307,
#    'cachedContents': {'non_null': '9334',
#     'largest': 'n/a',
#     'null': '0',
#     'top': [{'item': 'n/a', 'count': '101'},
#      {'item': 'gd01948', 'count': '1'},
#      {'item': 'ca00791', 'count': '1'},
#      {'item': 'gc03058', 'count': '1'},
#      {'item': 'gd01915', 'count': '1'},
#      {'item': 'ga01096', 'count': '1'},
#      {'item': 'gc03391', 'count': '1'},
#      {'item': 'eb03709', 'count': '1'},
#      {'item': 'eb03649', 'count': '1'},
#      {'item': 'eb02302', 'count': '1'},
#      {'item': 'eb05138', 'count': '1'},
#      {'item': 'ea00033', 'count': '1'},
#      {'item': 'gb02377', 'count': '1'},
#      {'item': 'fa00474', 'count': '1'},
#      {'item': 'gd01921', 'count': '1'},
#      {'item': 'cc01312', 'count': '1'},
#      {'item': 'fb00198a', 'count': '1'},
#      {'item': 'cc02553', 'count': '1'},
#      {'item': 'ga02890', 'count': '1'},
#      {'item': 'ea01538', 'count': '1'}],
#     'smallest': 'ca00001',
#     'count': '9334',
#     'cardinality': '9234'},
#    'format': {}},
#   {'id': 616490648,
#    'name': 'Cultural_R',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'cultural_r',
#    'position': 4,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165311,
#    'cachedContents': {'non_null': '9334',
#     'largest': '{FFF3B349-2B9F-8143-942A-1530AB13610F}',
#     'null': '0',
#     'top': [{'item': '{4145F814-2AAD-47ac-9627-F9ECEA30956C}', 'count': '2'},
#      {'item': '{C1ADDF27-DDB6-B943-B435-2606040E8D97}', 'count': '1'},
#      {'item': '{5A717F29-38D6-F445-B1EC-C723DE865809}', 'count': '1'},
#      {'item': '{FE2AF51F-D96E-422b-864F-6C93F3F74ADD}', 'count': '1'},
#      {'item': '{02DECBA4-23C8-4e12-9D44-9661E5ECA4E1}', 'count': '1'},
#      {'item': '{BF1C7FFB-D2C1-49a1-B153-8A957AA074C6}', 'count': '1'},
#      {'item': '{D59469C2-B9BD-9346-8137-83F5896CF2A8}', 'count': '1'},
#      {'item': '{96554155-6CA5-427d-A4F5-8C1642DE3D00}', 'count': '1'},
#      {'item': '{0901875D-040E-4d19-8F4F-2666E699E0EC}', 'count': '1'},
#      {'item': '{A3353285-45C9-4aa8-89EF-E6E1E73D6C90}', 'count': '1'},
#      {'item': '{7C378183-25B5-AA42-B8E2-42EA8AE32618}', 'count': '1'},
#      {'item': '{BBF92013-CCA1-4379-8EDB-5304737155D8}', 'count': '1'},
#      {'item': '{48B150CE-D944-C445-AC00-DBAFBE38C240}', 'count': '1'},
#      {'item': '{0BA7A8CD-DF9E-CF4F-8F25-18DD999D6F67}', 'count': '1'},
#      {'item': '{75663B31-3426-4786-A517-B8B89F6E033F}', 'count': '1'},
#      {'item': '{6CE4DCEB-C41F-44d9-9274-567194A9DEA2}', 'count': '1'},
#      {'item': '{55B7FA5E-6479-4c27-8BAD-7F2C4CD499A0}', 'count': '1'},
#      {'item': '{F764450B-81F8-45f7-A690-1AC1AD6E5184}', 'count': '1'},
#      {'item': '{481FBE1F-DB92-4c8a-8054-342CC1FD58EF}', 'count': '1'},
#      {'item': '{08E0652B-2B8B-44c0-B54B-4D727392A957}', 'count': '1'}],
#     'smallest': '{0001B7A4-01AC-4c4f-ABEE-956FFABB6FCD}',
#     'count': '9334',
#     'cardinality': '9333'},
#    'format': {}},
#   {'id': 616490708,
#    'name': 'Location_I',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'location_i',
#    'position': 5,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165371,
#    'cachedContents': {'non_null': '9334',
#     'largest': '{FFFA47EF-6DBF-4f4a-9C37-49247AE04811}',
#     'null': '0',
#     'top': [{'item': '{7330A320-30DA-43ec-A7FD-71258DB9926C}', 'count': '1'},
#      {'item': '{C7373A29-5F59-9245-829D-E48D8E771965}', 'count': '1'},
#      {'item': '{CE3DC0A5-F3FC-45b4-9035-37C439F5014D}', 'count': '1'},
#      {'item': '{05D1229E-1FCF-4b20-A1B1-CB236F065CDC}', 'count': '1'},
#      {'item': '{CABE621B-1745-8041-A1DC-8E80F451B2A7}', 'count': '1'},
#      {'item': '{6A762A0C-FF2C-45a0-9104-516E39045736}', 'count': '1'},
#      {'item': '{25D0D948-10B4-49ab-8889-E271CA26BD61}', 'count': '1'},
#      {'item': '{DF30F1BF-23F1-A240-A87D-FED77760C7C2}', 'count': '1'},
#      {'item': '{0FDCE8C8-9614-424E-A547-9C2A3E9FC4F1}', 'count': '1'},
#      {'item': '{22BADAE1-C42D-394F-8762-B84CBF574D68}', 'count': '1'},
#      {'item': '{9D11A356-7B94-4173-877B-164B12DCE68E}', 'count': '1'},
#      {'item': '{F6104F36-EF2C-6D4C-B3CD-5556FE8E76F8}', 'count': '1'},
#      {'item': '{ED2EB5ED-750E-9844-818D-E67622E5F355}', 'count': '1'},
#      {'item': '{F16CD676-625E-4f19-97D5-C819EC55CF9A}', 'count': '1'},
#      {'item': '{B358C7E9-1AD3-4d50-9FE9-83F78DF54AE5}', 'count': '1'},
#      {'item': '{45D6DA29-15DB-4434-9426-B8DDC87392F7}', 'count': '1'},
#      {'item': '{B2F9870D-DF7F-4331-97E3-3C25D7FB6E52}', 'count': '1'},
#      {'item': '{D455D278-5564-46bc-B889-77CD81784ED5}', 'count': '1'},
#      {'item': '{930889E8-93BE-EC4E-9971-FD7E2A2D6926}', 'count': '1'},
#      {'item': '{88C9680E-6434-46d5-90C0-87D1488705E0}', 'count': '1'}],
#     'smallest': '{0006A669-AD0F-4275-B9B9-75E955D57215}',
#     'count': '9334',
#     'cardinality': '9334'},
#    'format': {}},
#   {'id': 616490736,
#    'name': 'Survey_ID',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'survey_id',
#    'position': 6,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165399,
#    'cachedContents': {'non_null': '9334',
#     'largest': '{58FD1A36-0E60-41d7-8FDF-EC037D60D827}',
#     'null': '0',
#     'top': [{'item': '{58FD1A36-0E60-41d7-8FDF-EC037D60D827}',
#       'count': '9334'}],
#     'smallest': '{58FD1A36-0E60-41d7-8FDF-EC037D60D827}',
#     'count': '9334',
#     'cardinality': '1'},
#    'format': {}},
#   {'id': 616490741,
#    'name': 'Boundary_T',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'boundary_t',
#    'position': 7,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165404,
#    'cachedContents': {'non_null': '9334',
#     'largest': '9',
#     'null': '0',
#     'top': [{'item': '6', 'count': '5467'},
#      {'item': '7', 'count': '3102'},
#      {'item': '8', 'count': '764'},
#      {'item': '9', 'count': '1'}],
#     'smallest': '6',
#     'count': '9334',
#     'cardinality': '4'},
#    'format': {}},
#   {'id': 616490678,
#    'name': 'Map_Method',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'map_method',
#    'position': 8,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165341,
#    'cachedContents': {'non_null': '9334',
#     'largest': 'Digitized',
#     'null': '0',
#     'top': [{'item': '1', 'count': '9208'},
#      {'item': '8', 'count': '100'},
#      {'item': 'Digitized', 'count': '17'},
#      {'item': '10', 'count': '8'},
#      {'item': '9', 'count': '1'}],
#     'smallest': '1',
#     'count': '9334',
#     'cardinality': '5'},
#    'format': {}},
#   {'id': 616490764,
#    'name': 'Source',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'source',
#    'position': 9,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165427,
#    'cachedContents': {'non_null': '9334',
#     'largest': 'GPS',
#     'null': '0',
#     'top': [{'item': 'GPS', 'count': '9208'},
#      {'item': 'City of NO', 'count': '101'},
#      {'item': 'From Aerial', 'count': '25'}],
#     'smallest': 'City of NO',
#     'count': '9334',
#     'cardinality': '3'},
#    'format': {}},
#   {'id': 616490716,
#    'name': 'Source_Dat',
#    'dataTypeName': 'calendar_date',
#    'description': '',
#    'fieldName': 'source_dat',
#    'position': 10,
#    'renderTypeName': 'calendar_date',
#    'tableColumnId': 161165379,
#    'cachedContents': {'non_null': '9334',
#     'largest': '2009-03-10T00:00:00.000',
#     'null': '0',
#     'top': [{'item': '2005-12-20T00:00:00.000', 'count': '261'},
#      {'item': '2005-12-21T00:00:00.000', 'count': '210'},
#      {'item': '2007-07-24T00:00:00.000', 'count': '205'},
#      {'item': '2007-07-31T00:00:00.000', 'count': '185'},
#      {'item': '2007-07-30T00:00:00.000', 'count': '180'},
#      {'item': '2006-02-07T00:00:00.000', 'count': '179'},
#      {'item': '2007-06-28T00:00:00.000', 'count': '174'},
#      {'item': '2006-02-08T00:00:00.000', 'count': '166'},
#      {'item': '2007-07-23T00:00:00.000', 'count': '162'},
#      {'item': '2007-07-25T00:00:00.000', 'count': '157'},
#      {'item': '2007-08-01T00:00:00.000', 'count': '149'},
#      {'item': '2005-12-15T00:00:00.000', 'count': '148'},
#      {'item': '2006-02-06T00:00:00.000', 'count': '148'},
#      {'item': '2007-06-07T00:00:00.000', 'count': '144'},
#      {'item': '2007-06-06T00:00:00.000', 'count': '137'},
#      {'item': '2006-02-03T00:00:00.000', 'count': '133'},
#      {'item': '2007-07-12T00:00:00.000', 'count': '132'},
#      {'item': '2006-02-15T00:00:00.000', 'count': '127'},
#      {'item': '2006-02-09T00:00:00.000', 'count': '124'},
#      {'item': '2006-02-10T00:00:00.000', 'count': '120'}],
#     'smallest': '2005-12-12T00:00:00.000',
#     'count': '9334',
#     'cardinality': '218'},
#    'format': {}},
#   {'id': 616490777,
#    'name': 'Source_D_1',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'source_d_1',
#    'position': 11,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165440,
#    'cachedContents': {'non_null': '9334',
#     'largest': '3',
#     'null': '0',
#     'top': [{'item': '3', 'count': '9334'}],
#     'smallest': '3',
#     'count': '9334',
#     'cardinality': '1'},
#    'format': {}},
#   {'id': 616490746,
#    'name': 'Source_Coo',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'source_coo',
#    'position': 12,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165409,
#    'cachedContents': {'non_null': '9334',
#     'largest': '1',
#     'null': '0',
#     'top': [{'item': '1', 'count': '9334'}],
#     'smallest': '1',
#     'count': '9334',
#     'cardinality': '1'},
#    'format': {}},
#   {'id': 616490767,
#    'name': 'Source_Acc',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'source_acc',
#    'position': 13,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165430,
#    'cachedContents': {'non_null': '9334',
#     'largest': '+/- 5 Meters',
#     'null': '0',
#     'top': [{'item': '+/- 5 meters', 'count': '9152'},
#      {'item': '+/- 20 meters', 'count': '101'},
#      {'item': '+/- 5 Meters', 'count': '81'}],
#     'smallest': '+/- 20 meters',
#     'count': '9334',
#     'cardinality': '3'},
#    'format': {}},
#   {'id': 616490740,
#    'name': 'Last_Updat',
#    'dataTypeName': 'calendar_date',
#    'description': '',
#    'fieldName': 'last_updat',
#    'position': 14,
#    'renderTypeName': 'calendar_date',
#    'tableColumnId': 161165403,
#    'cachedContents': {'non_null': '9334',
#     'largest': '2009-04-27T00:00:00.000',
#     'null': '0',
#     'top': [{'item': '2006-01-25T00:00:00.000', 'count': '892'},
#      {'item': '2007-08-02T00:00:00.000', 'count': '333'},
#      {'item': '2007-07-24T00:00:00.000', 'count': '286'},
#      {'item': '2006-02-04T00:00:00.000', 'count': '225'},
#      {'item': '2007-07-25T00:00:00.000', 'count': '205'},
#      {'item': '2006-02-17T00:00:00.000', 'count': '200'},
#      {'item': '2007-07-27T00:00:00.000', 'count': '185'},
#      {'item': '2007-07-09T00:00:00.000', 'count': '183'},
#      {'item': '2006-02-08T00:00:00.000', 'count': '179'},
#      {'item': '2007-12-06T00:00:00.000', 'count': '178'},
#      {'item': '2007-07-19T00:00:00.000', 'count': '178'},
#      {'item': '2006-06-10T00:00:00.000', 'count': '173'},
#      {'item': '2007-07-12T00:00:00.000', 'count': '173'},
#      {'item': '2006-06-14T00:00:00.000', 'count': '172'},
#      {'item': '2006-02-09T00:00:00.000', 'count': '166'},
#      {'item': '2007-07-30T00:00:00.000', 'count': '158'},
#      {'item': '2007-05-07T00:00:00.000', 'count': '155'},
#      {'item': '2008-07-15T00:00:00.000', 'count': '154'},
#      {'item': '2007-06-08T00:00:00.000', 'count': '151'},
#      {'item': '2006-02-07T00:00:00.000', 'count': '148'}],
#     'smallest': '2006-01-05T00:00:00.000',
#     'count': '9334',
#     'cardinality': '152'},
#    'format': {}},
#   {'id': 616490748,
#    'name': 'Restrict_S',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'restrict_s',
#    'position': 15,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165411,
#    'cachedContents': {'non_null': '9334',
#     'largest': '1',
#     'null': '0',
#     'top': [{'item': '1', 'count': '9334'}],
#     'smallest': '1',
#     'count': '9334',
#     'cardinality': '1'},
#    'format': {}},
#   {'id': 616490723,
#    'name': 'Property_N',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'property_n',
#    'position': 16,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165386,
#    'cachedContents': {'non_null': '212',
#     'largest': "Winner's Supermarket",
#     'null': '9122',
#     'top': [{'item': 'Hearthwood East', 'count': '21'},
#      {'item': "Griffin's Bar", 'count': '2'},
#      {'item': "Mike's Food Store", 'count': '2'},
#      {'item': 'Rightway Food Store', 'count': '2'},
#      {'item': 'Asher Laundry', 'count': '1'},
#      {'item': 'Attorney Donald Pryor Legal Services', 'count': '1'},
#      {'item': 'Automotive Air Conditioning', 'count': '1'},
#      {'item': 'BarberShop.com', 'count': '1'},
#      {'item': 'Bethel Lutheran Church', 'count': '1'},
#      {'item': 'Bienville Restaurant', 'count': '1'},
#      {'item': 'Bordelon Auto Market Inc.', 'count': '1'},
#      {'item': 'Brake Shop', 'count': '1'},
#      {'item': 'Bright Morning Star Baptist Church', 'count': '1'},
#      {'item': 'Brothers Discount Market', 'count': '1'},
#      {'item': "Brown's", 'count': '1'},
#      {'item': "Brown's Donut Shop", 'count': '1'},
#      {'item': 'Caffin Food Store', 'count': '1'},
#      {'item': 'Calvin J. Young Funeral Home', 'count': '1'},
#      {'item': 'Chapel&HermitageOfSt.Raymond&OurLadyOfGoodHealth',
#       'count': '1'},
#      {'item': 'Chicken Box', 'count': '1'}],
#     'smallest': 'A Gift of Life Daycare',
#     'count': '9334',
#     'cardinality': '189'},
#    'format': {}},
#   {'id': 616490737,
#    'name': 'Street_Num',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'street_num',
#    'position': 17,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165400,
#    'cachedContents': {'non_null': '9333',
#     'largest': 'unknown',
#     'null': '1',
#     'top': [{'item': 'unknown', 'count': '44'},
#      {'item': '2427', 'count': '17'},
#      {'item': '2420', 'count': '14'},
#      {'item': '2600', 'count': '13'},
#      {'item': '2620', 'count': '12'},
#      {'item': '2500', 'count': '12'},
#      {'item': '2100', 'count': '12'},
#      {'item': '2316', 'count': '12'},
#      {'item': '1817', 'count': '11'},
#      {'item': '2401', 'count': '11'},
#      {'item': '2618', 'count': '11'},
#      {'item': '2000', 'count': '11'},
#      {'item': '2112', 'count': '11'},
#      {'item': '2330', 'count': '11'},
#      {'item': '2519', 'count': '11'},
#      {'item': '4819', 'count': '11'},
#      {'item': '1925', 'count': '10'},
#      {'item': '2601', 'count': '10'},
#      {'item': '2501', 'count': '10'},
#      {'item': '1924', 'count': '10'}],
#     'smallest': '?????',
#     'count': '9334',
#     'cardinality': '4803'},
#    'format': {}},
#   {'id': 616490747,
#    'name': 'Street_Nam',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'street_nam',
#    'position': 18,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165410,
#    'cachedContents': {'non_null': '9334',
#     'largest': 'Yardley Road',
#     'null': '0',
#     'top': [{'item': 'Forstall Street', 'count': '128'},
#      {'item': 'North Galvez Street', 'count': '126'},
#      {'item': 'Charbonnet Street', 'count': '121'},
#      {'item': 'Caffin Avenue', 'count': '111'},
#      {'item': 'Flood Street', 'count': '108'},
#      {'item': 'Deslonde Street', 'count': '107'},
#      {'item': 'Tennessee Street', 'count': '105'},
#      {'item': 'Louisa Street', 'count': '103'},
#      {'item': 'Lamanche Street', 'count': '102'},
#      {'item': 'Benton Street', 'count': '102'},
#      {'item': 'Delery Street', 'count': '100'},
#      {'item': 'Tricou Street', 'count': '98'},
#      {'item': 'North Tonti Street', 'count': '93'},
#      {'item': 'North Miro Street', 'count': '90'},
#      {'item': 'Andry Street', 'count': '90'},
#      {'item': 'Saint Maurice Avenue', 'count': '89'},
#      {'item': 'Gordon Street', 'count': '86'},
#      {'item': 'Alabo Street', 'count': '84'},
#      {'item': 'Reynes Street', 'count': '84'},
#      {'item': 'Egania Street', 'count': '83'}],
#     'smallest': '10th Street',
#     'count': '9334',
#     'cardinality': '1011'},
#    'format': {}},
#   {'id': 616490657,
#    'name': 'City_Tag',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'city_tag',
#    'position': 19,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165320,
#    'cachedContents': {'non_null': '9334',
#     'largest': 'yellow',
#     'null': '0',
#     'top': [{'item': 'none', 'count': '5329'},
#      {'item': 'red', 'count': '2254'},
#      {'item': 'unknown', 'count': '1160'},
#      {'item': 'other', 'count': '428'},
#      {'item': 'yellow', 'count': '97'},
#      {'item': 'removed', 'count': '63'},
#      {'item': 'green', 'count': '3'}],
#     'smallest': 'green',
#     'count': '9334',
#     'cardinality': '7'},
#    'format': {}},
#   {'id': 616490717,
#    'name': 'City_Datab',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'city_datab',
#    'position': 20,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165380,
#    'cachedContents': {'non_null': '9334',
#     'largest': 'unknown',
#     'null': '0',
#     'top': [{'item': 'bldg on city list', 'count': '8253'},
#      {'item': 'bldg not on city list', 'count': '880'},
#      {'item': 'unknown', 'count': '177'},
#      {'item': 'bldg not on cty list', 'count': '21'},
#      {'item': 'other', 'count': '3'}],
#     'smallest': 'bldg not on city list',
#     'count': '9334',
#     'cardinality': '5'},
#    'format': {}},
#   {'id': 616490781,
#    'name': 'Historic_N',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'historic_n',
#    'position': 21,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165444,
#    'cachedContents': {'non_null': '5082',
#     'largest': 'Zioncity/Gerttown',
#     'null': '4252',
#     'top': [{'item': 'Lower Ninth Ward', 'count': '348'},
#      {'item': 'Lakeview', 'count': '304'},
#      {'item': 'New Orleans East', 'count': '254'},
#      {'item': 'Gentilly', 'count': '245'},
#      {'item': 'No information available from residents.', 'count': '183'},
#      {'item': 'Mid-City', 'count': '161'},
#      {'item': 'none', 'count': '157'},
#      {'item': 'New Marigny', 'count': '124'},
#      {'item': 'Central City', 'count': '114'},
#      {'item': 'No information was given by residents.', 'count': '113'},
#      {'item': 'This building is in New Orleans East', 'count': '99'},
#      {'item': 'Bywater', 'count': '98'},
#      {'item': 'This building is in Lakeview.', 'count': '92'},
#      {'item': 'This building is in Gentilly', 'count': '86'},
#      {'item': 'This house is located in Gentilly.', 'count': '77'},
#      {'item': 'Ninth Ward', 'count': '76'},
#      {'item': 'This house is located in Lakeview.', 'count': '76'},
#      {'item': 'Uptown New Orleans Historic District', 'count': '75'},
#      {'item': 'This building is in the Ninth Ward', 'count': '71'},
#      {'item': 'This building is in the Seventh Ward', 'count': '65'}],
#     'smallest': '7th Ward',
#     'count': '9334',
#     'cardinality': '298'},
#    'format': {}},
#   {'id': 616490738,
#    'name': 'Constructi',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'constructi',
#    'position': 22,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165401,
#    'cachedContents': {'non_null': '9334',
#     'largest': 'Unknown',
#     'null': '0',
#     'top': [{'item': '1950', 'count': '874'},
#      {'item': '1920-30', 'count': '655'},
#      {'item': '1940', 'count': '612'},
#      {'item': '1960', 'count': '461'},
#      {'item': '1930', 'count': '354'},
#      {'item': '1950-60', 'count': '323'},
#      {'item': '1930-40', 'count': '320'},
#      {'item': '1945', 'count': '306'},
#      {'item': '1920', 'count': '295'},
#      {'item': '1945-55', 'count': '283'},
#      {'item': '1970', 'count': '280'},
#      {'item': 'Unknown', 'count': '275'},
#      {'item': '1940-50', 'count': '270'},
#      {'item': '1900-10', 'count': '219'},
#      {'item': '1980', 'count': '217'},
#      {'item': '1955', 'count': '200'},
#      {'item': '1940-55', 'count': '194'},
#      {'item': '1960-70', 'count': '191'},
#      {'item': '1925', 'count': '185'},
#      {'item': '1935', 'count': '180'}],
#     'smallest': '1820',
#     'count': '9334',
#     'cardinality': '119'},
#    'format': {}},
#   {'id': 616490766,
#    'name': 'Date_Estim',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'date_estim',
#    'position': 23,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165429,
#    'cachedContents': {'non_null': '9334',
#     'largest': 'Yes',
#     'null': '0',
#     'top': [{'item': 'Yes', 'count': '9307'}, {'item': 'No', 'count': '27'}],
#     'smallest': 'No',
#     'count': '9334',
#     'cardinality': '2'},
#    'format': {}},
#   {'id': 616490769,
#    'name': 'Less_than_',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'less_than_',
#    'position': 24,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165432,
#    'cachedContents': {'non_null': '9334',
#     'largest': 'yes',
#     'null': '0',
#     'top': [{'item': 'no', 'count': '7190'},
#      {'item': 'yes', 'count': '1564'},
#      {'item': 'unsure', 'count': '580'}],
#     'smallest': 'no',
#     'count': '9334',
#     'cardinality': '3'},
#    'format': {}},
#   {'id': 616490686,
#    'name': 'Listed_Sta',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'listed_sta',
#    'position': 25,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165349,
#    'cachedContents': {'non_null': '9219',
#     'largest': 'Unknown',
#     'null': '115',
#     'top': [{'item': 'none', 'count': '6074'},
#      {'item': 'Unknown', 'count': '1392'},
#      {'item': 'NR historic district', 'count': '1209'},
#      {'item': 'National Register', 'count': '163'},
#      {'item': 'Other', 'count': '112'},
#      {'item': 'unknown', 'count': '101'},
#      {'item': 'multiple', 'count': '94'},
#      {'item': 'local hist district', 'count': '67'},
#      {'item': 'Local listing', 'count': '7'}],
#     'smallest': 'local hist district',
#     'count': '9334',
#     'cardinality': '9'},
#    'format': {}},
#   {'id': 616490759,
#    'name': 'Contribute',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'contribute',
#    'position': 26,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165422,
#    'cachedContents': {'non_null': '9334',
#     'largest': 'Yes',
#     'null': '0',
#     'top': [{'item': 'No', 'count': '7048'},
#      {'item': 'Yes', 'count': '1286'},
#      {'item': 'Unknown', 'count': '930'},
#      {'item': 'Other', 'count': '70'}],
#     'smallest': 'No',
#     'count': '9334',
#     'cardinality': '4'},
#    'format': {}},
#   {'id': 616490739,
#    'name': 'Significan',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'significan',
#    'position': 27,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165402,
#    'cachedContents': {'non_null': '9333',
#     'largest': 'Would not contribute to the proposed Edgewood Park NHD because of alterations.',
#     'null': '1',
#     'top': [{'item': 'none', 'count': '1686'},
#      {'item': 'This building is not significant.', 'count': '667'},
#      {'item': 'This building does not possess the qualities of significance',
#       'count': '622'},
#      {'item': 'This building does not possess the qualities of significance.',
#       'count': '332'},
#      {'item': 'This structure does not possess the elements of significance.',
#       'count': '308'},
#      {'item': 'This building has no known significance.', 'count': '308'},
#      {'item': 'unknown', 'count': '274'},
#      {'item': 'This building is not significant', 'count': '256'},
#      {'item': 'This common type is not significant.', 'count': '235'},
#      {'item': 'This structure does not possess qualities of significance.',
#       'count': '208'},
#      {'item': 'This building does not contribute.', 'count': '197'},
#      {'item': 'not significant', 'count': '190'},
#      {'item': 'Possesses no elements of significance.', 'count': '177'},
#      {'item': 'There is no known significance associated with this structure.',
#       'count': '137'},
#      {'item': 'This structure does not possess the qualities of significance.',
#       'count': '117'},
#      {'item': 'This building has no significance.', 'count': '107'},
#      {'item': 'This common building type is not significant.', 'count': '81'},
#      {'item': 'architectural', 'count': '78'},
#      {'item': 'This building does possess the qualities of significance',
#       'count': '56'},
#      {'item': 'This building contributes to the Mid-City NRHD under Criterion C.',
#       'count': '55'}],
#     'smallest': 'adjacent to bywater hd',
#     'count': '9334',
#     'cardinality': '865'},
#    'format': {}},
#   {'id': 616490714,
#    'name': 'Historic_C',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'historic_c',
#    'position': 28,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165377,
#    'cachedContents': {'non_null': '8338',
#     'largest': 'Zioncity/Gerttown neighborhood near Interstate 10.',
#     'null': '996',
#     'top': [{'item': 'Neighborhood consists of early to mid twentieth century homes',
#       'count': '276'},
#      {'item': 'This is a residential area', 'count': '187'},
#      {'item': 'Neighborhood consists of mid to late twentieth century homes',
#       'count': '154'},
#      {'item': 'most bldgs on block destroyed', 'count': '130'},
#      {'item': 'Neighborhood consists of early twentieth century residences.',
#       'count': '124'},
#      {'item': 'This building is located in the historic Lower Ninth Ward.',
#       'count': '107'},
#      {'item': 'none', 'count': '97'},
#      {'item': 'This property is located in a mid twentieth century urban african american residential neighborhood.',
#       'count': '93'},
#      {'item': 'This building is in Lakeview.', 'count': '92'},
#      {'item': 'most buildings on block destroyed', 'count': '82'},
#      {'item': 'Neighborhood consists of late nineteenth to early twentieth century residences.',
#       'count': '77'},
#      {'item': 'residential', 'count': '76'},
#      {'item': 'This house is located in Lakeview.', 'count': '76'},
#      {'item': 'This house is located in Gentilly.', 'count': '75'},
#      {'item': 'Neighborhood consists of late 19th to early 20th century residences.',
#       'count': '64'},
#      {'item': 'Neighborhood consists of twentieth century residences.',
#       'count': '63'},
#      {'item': 'Neighborhood consists of mid twentieth century residences.',
#       'count': '62'},
#      {'item': 'This building is in the Lower Ninth Ward', 'count': '55'},
#      {'item': 'This building is in the Seventh Ward', 'count': '55'},
#      {'item': 'This structure is in New Orleans East.', 'count': '52'}],
#     'smallest': '1950s neighborhood',
#     'count': '9334',
#     'cardinality': '1460'},
#    'format': {}},
#   {'id': 616490724,
#    'name': 'Materials_',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'materials_',
#    'position': 29,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165387,
#    'cachedContents': {'non_null': '9334',
#     'largest': 'yes',
#     'null': '0',
#     'top': [{'item': 'no', 'count': '5356'},
#      {'item': 'yes', 'count': '3819'},
#      {'item': 'unsure', 'count': '158'},
#      {'item': 'unknown', 'count': '1'}],
#     'smallest': 'no',
#     'count': '9334',
#     'cardinality': '4'},
#    'format': {}},
#   {'id': 616490750,
#    'name': 'Design_Int',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'design_int',
#    'position': 30,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165413,
#    'cachedContents': {'non_null': '9334',
#     'largest': 'yes',
#     'null': '0',
#     'top': [{'item': 'yes', 'count': '4699'},
#      {'item': 'no', 'count': '4489'},
#      {'item': 'unsure', 'count': '146'}],
#     'smallest': 'no',
#     'count': '9334',
#     'cardinality': '3'},
#    'format': {}},
#   {'id': 616490771,
#    'name': 'Wrkmanship',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'wrkmanship',
#    'position': 31,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165434,
#    'cachedContents': {'non_null': '9334',
#     'largest': 'yes',
#     'null': '0',
#     'top': [{'item': 'no', 'count': '6145'},
#      {'item': 'yes', 'count': '3077'},
#      {'item': 'unsure', 'count': '112'}],
#     'smallest': 'no',
#     'count': '9334',
#     'cardinality': '3'},
#    'format': {}},
#   {'id': 616490745,
#    'name': 'Setting_In',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'setting_in',
#    'position': 32,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165408,
#    'cachedContents': {'non_null': '9334',
#     'largest': 'yes',
#     'null': '0',
#     'top': [{'item': 'yes', 'count': '6016'},
#      {'item': 'no', 'count': '3187'},
#      {'item': 'unsure', 'count': '131'}],
#     'smallest': 'no',
#     'count': '9334',
#     'cardinality': '3'},
#    'format': {}},
#   {'id': 616490713,
#    'name': 'Location_1',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'location_1',
#    'position': 33,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165376,
#    'cachedContents': {'non_null': '9334',
#     'largest': 'yes',
#     'null': '0',
#     'top': [{'item': 'yes', 'count': '8395'},
#      {'item': 'no', 'count': '913'},
#      {'item': 'unsure', 'count': '24'},
#      {'item': '{3837E8FF-EA0F-4d0a-978F-827D622581DA}', 'count': '1'},
#      {'item': '{24E7532A-F24C-4916-9816-8FB6F055BEEF}', 'count': '1'}],
#     'smallest': '{24E7532A-F24C-4916-9816-8FB6F055BEEF}',
#     'count': '9334',
#     'cardinality': '5'},
#    'format': {}},
#   {'id': 616490773,
#    'name': 'Foundatio2',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'foundatio2',
#    'position': 34,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165436,
#    'cachedContents': {'non_null': '9334',
#     'largest': 'unknown',
#     'null': '0',
#     'top': [{'item': 'intact', 'count': '3720'},
#      {'item': 'building on', 'count': '2535'},
#      {'item': 'damaged', 'count': '1363'},
#      {'item': 'building off', 'count': '1333'},
#      {'item': 'unknown', 'count': '354'},
#      {'item': 'other', 'count': '29'}],
#     'smallest': 'building off',
#     'count': '9334',
#     'cardinality': '6'},
#    'format': {}},
#   {'id': 616490722,
#    'name': 'Wall_Condi',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'wall_condi',
#    'position': 35,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165385,
#    'cachedContents': {'non_null': '9334',
#     'largest': 'unknown',
#     'null': '0',
#     'top': [{'item': 'minor damage', 'count': '3017'},
#      {'item': 'intact', 'count': '2920'},
#      {'item': 'racked', 'count': '1376'},
#      {'item': 'partial collapse', 'count': '1089'},
#      {'item': 'other', 'count': '394'},
#      {'item': 'total collapse', 'count': '349'},
#      {'item': 'unknown', 'count': '189'}],
#     'smallest': 'intact',
#     'count': '9334',
#     'cardinality': '7'},
#    'format': {}},
#   {'id': 616490660,
#    'name': 'Roof_Condi',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'roof_condi',
#    'position': 36,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165323,
#    'cachedContents': {'non_null': '9334',
#     'largest': 'unknown',
#     'null': '0',
#     'top': [{'item': 'damaged', 'count': '6706'},
#      {'item': 'intact', 'count': '1548'},
#      {'item': 'total collapse', 'count': '436'},
#      {'item': 'partial collapse', 'count': '314'},
#      {'item': 'unknown', 'count': '202'},
#      {'item': 'missing', 'count': '109'},
#      {'item': 'other', 'count': '19'}],
#     'smallest': 'damaged',
#     'count': '9334',
#     'cardinality': '7'},
#    'format': {}},
#   {'id': 616490768,
#    'name': 'Damage_Typ',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'damage_typ',
#    'position': 37,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165431,
#    'cachedContents': {'non_null': '9306',
#     'largest': 'wind',
#     'null': '28',
#     'top': [{'item': 'multiple', 'count': '7752'},
#      {'item': 'water', 'count': '765'},
#      {'item': 'unknown', 'count': '256'},
#      {'item': 'none', 'count': '174'},
#      {'item': 'deferred maintenance', 'count': '164'},
#      {'item': 'fire', 'count': '102'},
#      {'item': 'wind', 'count': '90'},
#      {'item': 'other', 'count': '3'}],
#     'smallest': 'deferred maintenance',
#     'count': '9334',
#     'cardinality': '8'},
#    'format': {}},
#   {'id': 616490765,
#    'name': 'Current_Us',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'current_us',
#    'position': 38,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165428,
#    'cachedContents': {'non_null': '9233',
#     'largest': 'warehouse',
#     'null': '101',
#     'top': [{'item': 'single dwelling', 'count': '4641'},
#      {'item': 'vacant', 'count': '2431'},
#      {'item': 'multiple dwelling', 'count': '1593'},
#      {'item': 'unknown', 'count': '241'},
#      {'item': 'commercial', 'count': '169'},
#      {'item': 'religious', 'count': '41'},
#      {'item': 'other', 'count': '38'},
#      {'item': 'multiple', 'count': '32'},
#      {'item': 'other residential', 'count': '23'},
#      {'item': 'other storage', 'count': '12'},
#      {'item': 'utility', 'count': '3'},
#      {'item': 'hotel', 'count': '3'},
#      {'item': 'fire station', 'count': '2'},
#      {'item': 'government', 'count': '1'},
#      {'item': 'recreation', 'count': '1'},
#      {'item': 'industrial', 'count': '1'},
#      {'item': 'warehouse', 'count': '1'}],
#     'smallest': 'commercial',
#     'count': '9334',
#     'cardinality': '17'},
#    'format': {}},
#   {'id': 616490751,
#    'name': 'Style',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'style',
#    'position': 39,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165414,
#    'cachedContents': {'non_null': '9334',
#     'largest': 'unknown',
#     'null': '0',
#     'top': [{'item': 'No style', 'count': '3856'},
#      {'item': 'other', 'count': '2159'},
#      {'item': 'Craftsman', 'count': '1386'},
#      {'item': 'unknown', 'count': '1273'},
#      {'item': '20th Cen. Revival', 'count': '145'},
#      {'item': 'Eastlake', 'count': '107'},
#      {'item': 'Creole', 'count': '84'},
#      {'item': 'Italianate', 'count': '82'},
#      {'item': 'Classical Revival', 'count': '63'},
#      {'item': 'Queen Anne', 'count': '53'},
#      {'item': 'Colonial Revival', 'count': '47'},
#      {'item': 'Greek Revival', 'count': '31'},
#      {'item': 'Art Deco', 'count': '13'},
#      {'item': 'Queen Anne Revival', 'count': '9'},
#      {'item': 'International', 'count': '9'},
#      {'item': 'Federal', 'count': '4'},
#      {'item': 'Spanish Colonial', 'count': '4'},
#      {'item': 'Moderne', 'count': '3'},
#      {'item': 'French Colonial', 'count': '3'},
#      {'item': 'Gothic Revival', 'count': '2'}],
#     'smallest': '20th Cen. Revival',
#     'count': '9334',
#     'cardinality': '21'},
#    'format': {}},
#   {'id': 616490720,
#    'name': 'Building_T',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'building_t',
#    'position': 40,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165383,
#    'cachedContents': {'non_null': '9334',
#     'largest': 'warehouse',
#     'null': '0',
#     'top': [{'item': 'minimal traditional', 'count': '1950'},
#      {'item': 'double shotgun', 'count': '1558'},
#      {'item': 'shotgun', 'count': '1363'},
#      {'item': 'other', 'count': '1329'},
#      {'item': 'ranch', 'count': '1197'},
#      {'item': 'bungalow', 'count': '770'},
#      {'item': 'unknown', 'count': '342'},
#      {'item': 'commercial', 'count': '246'},
#      {'item': 'camelback', 'count': '199'},
#      {'item': 'creole cottage', 'count': '138'},
#      {'item': 'raised basement', 'count': '68'},
#      {'item': 'side-hall', 'count': '46'},
#      {'item': 'central hall', 'count': '33'},
#      {'item': 'Gable-Ell', 'count': '27'},
#      {'item': 'warehouse', 'count': '13'},
#      {'item': 'garage', 'count': '12'},
#      {'item': 'American townhouse', 'count': '12'},
#      {'item': 'storage', 'count': '9'},
#      {'item': 'dependency', 'count': '7'},
#      {'item': 'four square', 'count': '6'}],
#     'smallest': 'American townhouse',
#     'count': '9334',
#     'cardinality': '24'},
#    'format': {}},
#   {'id': 616490729,
#    'name': 'Footprint',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'footprint',
#    'position': 41,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165392,
#    'cachedContents': {'non_null': '9334',
#     'largest': 'U-shaped',
#     'null': '0',
#     'top': [{'item': 'rectangular', 'count': '6873'},
#      {'item': 'L-shaped', 'count': '891'},
#      {'item': 'irregular', 'count': '766'},
#      {'item': 'unknown', 'count': '380'},
#      {'item': 'square', 'count': '324'},
#      {'item': 'T-shaped', 'count': '39'},
#      {'item': 'U-shaped', 'count': '39'},
#      {'item': 'other', 'count': '17'},
#      {'item': 'cross-gabled', 'count': '4'},
#      {'item': 'cruciform', 'count': '1'}],
#     'smallest': 'cross-gabled',
#     'count': '9334',
#     'cardinality': '10'},
#    'format': {}},
#   {'id': 616490673,
#    'name': 'Height',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'height',
#    'position': 42,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165336,
#    'cachedContents': {'non_null': '9334',
#     'largest': 'unknown',
#     'null': '0',
#     'top': [{'item': '1', 'count': '7682'},
#      {'item': '2', 'count': '1037'},
#      {'item': 'unknown', 'count': '293'},
#      {'item': '1.5', 'count': '247'},
#      {'item': '3', 'count': '33'},
#      {'item': '2.5', 'count': '32'},
#      {'item': 'other', 'count': '9'},
#      {'item': '4', 'count': '1'}],
#     'smallest': '1',
#     'count': '9334',
#     'cardinality': '8'},
#    'format': {}},
#   {'id': 616490718,
#    'name': 'Foundation',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'foundation',
#    'position': 43,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165381,
#    'cachedContents': {'non_null': '9334',
#     'largest': 'wooden piling',
#     'null': '0',
#     'top': [{'item': 'concrete slab', 'count': '2374'},
#      {'item': 'unknown', 'count': '1612'},
#      {'item': 'brick pier', 'count': '1382'},
#      {'item': 'concrete block pier', 'count': '1257'},
#      {'item': 'concrete block', 'count': '776'},
#      {'item': 'concrete pier', 'count': '711'},
#      {'item': 'multiple', 'count': '487'},
#      {'item': 'continuous concrete', 'count': '340'},
#      {'item': 'continuous brick', 'count': '290'},
#      {'item': 'other', 'count': '57'},
#      {'item': 'wooden piling', 'count': '17'},
#      {'item': 'stone pier', 'count': '9'},
#      {'item': 'wooden pier', 'count': '8'},
#      {'item': 'continuous stone', 'count': '7'},
#      {'item': 'concrete pylon pier', 'count': '3'},
#      {'item': 'sill on ground', 'count': '3'},
#      {'item': 'concrete pylon', 'count': '1'}],
#     'smallest': 'brick pier',
#     'count': '9334',
#     'cardinality': '17'},
#    'format': {}},
#   {'id': 616490719,
#    'name': 'Const_Mate',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'const_mate',
#    'position': 44,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165382,
#    'cachedContents': {'non_null': '9334',
#     'largest': 'unknown',
#     'null': '0',
#     'top': [{'item': 'frame', 'count': '7606'},
#      {'item': 'balloon frame', 'count': '768'},
#      {'item': 'unknown', 'count': '233'},
#      {'item': 'timber frame', 'count': '174'},
#      {'item': 'brick', 'count': '150'},
#      {'item': 'concrete block', 'count': '143'},
#      {'item': 'multiple', 'count': '116'},
#      {'item': 'barge-board', 'count': '79'},
#      {'item': 'stucco', 'count': '21'},
#      {'item': 'steel frame', 'count': '19'},
#      {'item': 'other', 'count': '16'},
#      {'item': 'metal', 'count': '7'},
#      {'item': 'stone', 'count': '1'},
#      {'item': 'log', 'count': '1'}],
#     'smallest': 'balloon frame',
#     'count': '9334',
#     'cardinality': '14'},
#    'format': {}},
#   {'id': 616490699,
#    'name': 'Cladding',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'cladding',
#    'position': 45,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165362,
#    'cachedContents': {'non_null': '9334',
#     'largest': 'wood',
#     'null': '0',
#     'top': [{'item': 'wood', 'count': '2950'},
#      {'item': 'masonry', 'count': '1553'},
#      {'item': 'multiple', 'count': '1387'},
#      {'item': 'unknown', 'count': '1273'},
#      {'item': 'vinyl', 'count': '1109'},
#      {'item': 'other', 'count': '365'},
#      {'item': 'stucco', 'count': '318'},
#      {'item': 'metal', 'count': '235'},
#      {'item': 'shingle', 'count': '79'},
#      {'item': 'concrete', 'count': '65'}],
#     'smallest': 'concrete',
#     'count': '9334',
#     'cardinality': '10'},
#    'format': {}},
#   {'id': 616490725,
#    'name': 'Roof_Mate',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'roof_mate',
#    'position': 46,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165388,
#    'cachedContents': {'non_null': '9334',
#     'largest': 'wood shingle',
#     'null': '0',
#     'top': [{'item': 'asphalt shingle', 'count': '6315'},
#      {'item': 'asbestos shingle', 'count': '1695'},
#      {'item': 'unknown', 'count': '560'},
#      {'item': 'multiple', 'count': '237'},
#      {'item': 'slate', 'count': '203'},
#      {'item': 'metal', 'count': '196'},
#      {'item': 'other', 'count': '86'},
#      {'item': 'tile', 'count': '41'},
#      {'item': 'wood shingle', 'count': '1'}],
#     'smallest': 'asbestos shingle',
#     'count': '9334',
#     'cardinality': '9'},
#    'format': {}},
#   {'id': 616490774,
#    'name': 'Roof_Type',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'roof_type',
#    'position': 47,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165437,
#    'cachedContents': {'non_null': '9334',
#     'largest': 'unknown',
#     'null': '0',
#     'top': [{'item': 'front gable', 'count': '3017'},
#      {'item': 'hip', 'count': '2676'},
#      {'item': 'side gable', 'count': '967'},
#      {'item': 'gable on hip', 'count': '711'},
#      {'item': 'multiple', 'count': '710'},
#      {'item': 'unknown', 'count': '472'},
#      {'item': 'cross gable', 'count': '337'},
#      {'item': 'flat', 'count': '134'},
#      {'item': 'other', 'count': '119'},
#      {'item': 'clipped gable', 'count': '79'},
#      {'item': 'shed', 'count': '30'},
#      {'item': 'parapet gable', 'count': '29'},
#      {'item': 'pyramidal', 'count': '25'},
#      {'item': 'mansard', 'count': '21'},
#      {'item': 'gambrel', 'count': '7'}],
#     'smallest': 'clipped gable',
#     'count': '9334',
#     'cardinality': '15'},
#    'format': {}},
#   {'id': 616490784,
#    'name': 'Chimneys',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'chimneys',
#    'position': 48,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165447,
#    'cachedContents': {'non_null': '8879',
#     'largest': 'unknown',
#     'null': '455',
#     'top': [{'item': 'none', 'count': '6128'},
#      {'item': 'unknown', 'count': '1499'},
#      {'item': 'ridge, off-center', 'count': '361'},
#      {'item': 'multiple', 'count': '294'},
#      {'item': 'ridge center', 'count': '259'},
# ...
#    'fieldName': 'd_zone',
#    'position': 87,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165426,
#    'cachedContents': {'non_null': '8620',
#     'largest': '<Null>',
#     'null': '714',
#     'top': [{'item': '17 B', 'count': '496'},
#      {'item': '17 A', 'count': '332'},
#      {'item': '25 B', 'count': '325'},
#      {'item': '18 A', 'count': '208'},
#      {'item': '19-B4', 'count': '194'},
#      {'item': '19-B2', 'count': '161'},
#      {'item': '17 C-2', 'count': '150'},
#      {'item': '17 E-1', 'count': '139'},
#      {'item': '15 C', 'count': '135'},
#      {'item': '17 E-12', 'count': '134'},
#      {'item': '17 C-1', 'count': '131'},
#      {'item': '17 D-2', 'count': '129'},
#      {'item': '17 D-10', 'count': '129'},
#      {'item': '19-B1', 'count': '125'},
#      {'item': '17 E-10', 'count': '118'},
#      {'item': '17 D-1', 'count': '113'},
#      {'item': '26-D11', 'count': '110'},
#      {'item': '17 D-9', 'count': '106'},
#      {'item': '17 E-2', 'count': '105'},
#      {'item': '17 D-4', 'count': '104'}],
#     'smallest': '12 A',
#     'count': '9334',
#     'cardinality': '250'},
#    'format': {}},
#   {'id': 616490772,
#    'name': 'D_List',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'd_list',
#    'position': 88,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165435,
#    'cachedContents': {'non_null': '9334',
#     'largest': 'Y-Removed',
#     'null': '0',
#     'top': [{'item': 'C', 'count': '1702'},
#      {'item': 'P', 'count': '1339'},
#      {'item': 'O', 'count': '564'},
#      {'item': 'F', 'count': '542'},
#      {'item': 'no list', 'count': '519'},
#      {'item': 'I', 'count': '515'},
#      {'item': 'K', 'count': '501'},
#      {'item': 'H', 'count': '451'},
#      {'item': 'M', 'count': '429'},
#      {'item': 'N', 'count': '358'},
#      {'item': 'P-Removed', 'count': '314'},
#      {'item': 'R', 'count': '300'},
#      {'item': 'J', 'count': '236'},
#      {'item': 'W', 'count': '234'},
#      {'item': 'Q', 'count': '232'},
#      {'item': 'L', 'count': '224'},
#      {'item': 'Y', 'count': '201'},
#      {'item': 'X', 'count': '183'},
#      {'item': 'S', 'count': '108'},
#      {'item': 'N-Commercial', 'count': '78'}],
#     'smallest': 'C',
#     'count': '9334',
#     'cardinality': '49'},
#    'format': {}},
#   {'id': 616490753,
#    'name': 'SHPO_Consu',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'shpo_consu',
#    'position': 89,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165416,
#    'cachedContents': {'non_null': '9334',
#     'largest': 'Or-C Eligible-R',
#     'null': '0',
#     'top': [{'item': '9/16/2007', 'count': '1510'},
#      {'item': '6/22/2006', 'count': '1413'},
#      {'item': 'not applicable', 'count': '713'},
#      {'item': '8/02/2007', 'count': '564'},
#      {'item': '7/9/2006', 'count': '517'},
#      {'item': '1/30/2007', 'count': '514'},
#      {'item': '4/01/2007', 'count': '467'},
#      {'item': '1/23/2007', 'count': '451'},
#      {'item': '6/20/2007', 'count': '418'},
#      {'item': '7/24/2007', 'count': '357'},
#      {'item': '7/09/2007', 'count': '300'},
#      {'item': '1/08/2008', 'count': '288'},
#      {'item': '7/24/2008', 'count': '239'},
#      {'item': '4/10/2007', 'count': '227'},
#      {'item': '11/19/2007', 'count': '220'},
#      {'item': '5/25/2006', 'count': '213'},
#      {'item': '10/10/2008', 'count': '200'},
#      {'item': '10/8/2008', 'count': '183'},
#      {'item': '1/29/2008', 'count': '104'},
#      {'item': '7/12/2006', 'count': '71'}],
#     'smallest': '10/10/2008',
#     'count': '9334',
#     'cardinality': '66'},
#    'format': {}},
#   {'id': 616490730,
#    'name': 'Arch_Tier',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'arch_tier',
#    'position': 90,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165393,
#    'cachedContents': {'non_null': '8560',
#     'largest': 'T2M',
#     'null': '774',
#     'top': [{'item': 'T0', 'count': '3897'},
#      {'item': 'T0M', 'count': '1247'},
#      {'item': 'T0L', 'count': '977'},
#      {'item': 'T0H', 'count': '969'},
#      {'item': 'T2H', 'count': '811'},
#      {'item': 'T1M', 'count': '252'},
#      {'item': 'T2M', 'count': '202'},
#      {'item': 'T1L', 'count': '100'},
#      {'item': 'T2L', 'count': '87'},
#      {'item': 'SHPO', 'count': '15'},
#      {'item': 'T1H', 'count': '3'}],
#     'smallest': 'SHPO',
#     'count': '9334',
#     'cardinality': '11'},
#    'format': {}},
#   {'id': 616490778,
#    'name': 'Zipcode',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'zipcode',
#    'position': 91,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165441,
#    'cachedContents': {'non_null': '9334',
#     'largest': '70131',
#     'null': '0',
#     'top': [{'item': '70117', 'count': '3475'},
#      {'item': '70122', 'count': '1127'},
#      {'item': '70126', 'count': '999'},
#      {'item': '70124', 'count': '793'},
#      {'item': '70119', 'count': '743'},
#      {'item': '70125', 'count': '456'},
#      {'item': '70118', 'count': '311'},
#      {'item': '70127', 'count': '288'},
#      {'item': '70115', 'count': '259'},
#      {'item': '70116', 'count': '239'},
#      {'item': '70113', 'count': '165'},
#      {'item': '70128', 'count': '119'},
#      {'item': '70129', 'count': '116'},
#      {'item': '70114', 'count': '114'},
#      {'item': '70130', 'count': '59'},
#      {'item': '70112', 'count': '44'},
#      {'item': '70131', 'count': '26'},
#      {'item': '70032', 'count': '1'}],
#     'smallest': '70032',
#     'count': '9334',
#     'cardinality': '18'},
#    'format': {}},
#   {'id': 616490731,
#    'name': 'Address',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'address',
#    'position': 92,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165394,
#    'cachedContents': {'non_null': '9334',
#     'largest': 'unknown unknown',
#     'null': '0',
#     'top': [{'item': 'unknown unknown', 'count': '23'},
#      {'item': 'unknown Tennessee Street', 'count': '9'},
#      {'item': 'unknown Tupelo Street', 'count': '5'},
#      {'item': '1220 North Tonti Street', 'count': '3'},
#      {'item': '1838 Charbonnet Street', 'count': '3'},
#      {'item': '5414 North Galvez Street', 'count': '3'},
#      {'item': '924 South Telemachus Street', 'count': '3'},
#      {'item': '1609 Delery Street', 'count': '3'},
#      {'item': '4601-03 South Miro Street', 'count': '3'},
#      {'item': '1400 Saint Maurice Avenue', 'count': '2'},
#      {'item': '1625 Kerlerec Street', 'count': '2'},
#      {'item': '2826 Clouet Street', 'count': '2'},
#      {'item': '2415 Urquhart Street', 'count': '2'},
#      {'item': '2204 Foucher Street', 'count': '2'},
#      {'item': '5205 North Galvez Street', 'count': '2'},
#      {'item': '2814 Dryades Street', 'count': '2'},
#      {'item': '3526-28 Washington Avenue', 'count': '2'},
#      {'item': '1723 Flood Street', 'count': '2'},
#      {'item': '2019-21 Benton Street', 'count': '2'},
#      {'item': '1615 Louisa Street', 'count': '2'}],
#     'smallest': '1000-02 Pleasant Street',
#     'count': '9334',
#     'cardinality': '9164'},
#    'format': {}},
#   {'id': 616490663,
#    'name': 'DemoStatus',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'demostatus',
#    'position': 93,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165326,
#    'cachedContents': {'non_null': '9334',
#     'largest': 'USACE SSR 9/8/2007',
#     'null': '0',
#     'top': [{'item': 'no information provided', 'count': '3962'},
#      {'item': 'USACE 8/12/2006', 'count': '53'},
#      {'item': 'USACE 8/15/2006', 'count': '42'},
#      {'item': 'USACE 12/9/2006', 'count': '39'},
#      {'item': 'USACE 8/6/2006', 'count': '39'},
#      {'item': 'USACE 12/6/2006', 'count': '37'},
#      {'item': 'USACE 12/11/2006', 'count': '37'},
#      {'item': 'USACE 12/10/2006', 'count': '36'},
#      {'item': 'USACE 8/11/2006', 'count': '35'},
#      {'item': 'USACE 8/8/2006', 'count': '35'},
#      {'item': 'USACE 12/14/2006', 'count': '34'},
#      {'item': 'USACE 12/13/2006', 'count': '34'},
#      {'item': 'USACE 8/10/2006', 'count': '31'},
#      {'item': 'USACE 8/18/2006', 'count': '31'},
#      {'item': 'USACE 8/7/2006', 'count': '31'},
#      {'item': 'USACE 12/15/2006', 'count': '31'},
#      {'item': 'USACE 12/2/2006', 'count': '30'},
#      {'item': 'USACE 12/17/2006', 'count': '30'},
#      {'item': 'USACE 8/9/2006', 'count': '30'},
#      {'item': 'USACE 12/8/2006', 'count': '29'}],
#     'smallest': '12/11/2006',
#     'count': '9334',
#     'cardinality': '921'},
#    'format': {}},
#   {'id': 616490711,
#    'name': 'DemoInfo',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'demoinfo',
#    'position': 94,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165374,
#    'cachedContents': {'non_null': '0',
#     'null': '9334',
#     'count': '9334',
#     'cardinality': '0'},
#    'format': {}},
#   {'id': 616490783,
#    'name': 'ST_Num',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'st_num',
#    'position': 95,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165446,
#    'cachedContents': {'non_null': '9333',
#     'largest': 'unknown',
#     'null': '1',
#     'top': [{'item': 'unknown', 'count': '44'},
#      {'item': '2427', 'count': '17'},
#      {'item': '2420', 'count': '14'},
#      {'item': '2600', 'count': '13'},
#      {'item': '2620', 'count': '12'},
#      {'item': '2500', 'count': '12'},
#      {'item': '2100', 'count': '12'},
#      {'item': '2316', 'count': '12'},
#      {'item': '1817', 'count': '11'},
#      {'item': '2401', 'count': '11'},
#      {'item': '2618', 'count': '11'},
#      {'item': '2000', 'count': '11'},
#      {'item': '2112', 'count': '11'},
#      {'item': '2330', 'count': '11'},
#      {'item': '2519', 'count': '11'},
#      {'item': '4819', 'count': '11'},
#      {'item': '1925', 'count': '10'},
#      {'item': '2601', 'count': '10'},
#      {'item': '2501', 'count': '10'},
#      {'item': '1924', 'count': '10'}],
#     'smallest': '?????',
#     'count': '9334',
#     'cardinality': '4803'},
#    'format': {}},
#   {'id': 616490755,
#    'name': 'ST_Dir',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'st_dir',
#    'position': 96,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165418,
#    'cachedContents': {'non_null': '1267',
#     'largest': 'West',
#     'null': '8067',
#     'top': [{'item': 'North', 'count': '863'},
#      {'item': 'South', 'count': '345'},
#      {'item': 'West', 'count': '46'},
#      {'item': 'East', 'count': '13'}],
#     'smallest': 'East',
#     'count': '9334',
#     'cardinality': '4'},
#    'format': {}},
#   {'id': 616490635,
#    'name': 'ST_Name',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'st_name',
#    'position': 97,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165298,
#    'cachedContents': {'non_null': '9334',
#     'largest': 'Yardley',
#     'null': '0',
#     'top': [{'item': 'Galvez', 'count': '144'},
#      {'item': 'Forstall', 'count': '128'},
#      {'item': 'Charbonnet', 'count': '121'},
#      {'item': 'Caffin', 'count': '111'},
#      {'item': 'Miro', 'count': '109'},
#      {'item': 'Flood', 'count': '108'},
#      {'item': 'Deslonde', 'count': '107'},
#      {'item': 'Louisa', 'count': '106'},
#      {'item': 'Tennessee', 'count': '105'},
#      {'item': 'Benton', 'count': '102'},
#      {'item': 'Lamanche', 'count': '102'},
#      {'item': 'Tonti', 'count': '101'},
#      {'item': 'Delery', 'count': '100'},
#      {'item': 'Tricou', 'count': '98'},
#      {'item': 'Andry', 'count': '90'},
#      {'item': 'Saint Maurice', 'count': '89'},
#      {'item': 'Gordon', 'count': '86'},
#      {'item': 'Reynes', 'count': '84'},
#      {'item': 'Alabo', 'count': '84'},
#      {'item': 'Feliciana', 'count': '83'}],
#     'smallest': '10th',
#     'count': '9334',
#     'cardinality': '929'},
#    'format': {}},
#   {'id': 616490735,
#    'name': 'ST_Suffix',
#    'dataTypeName': 'text',
#    'description': '',
#    'fieldName': 'st_suffix',
#    'position': 98,
#    'renderTypeName': 'text',
#    'tableColumnId': 161165398,
#    'cachedContents': {'non_null': '9303',
#     'largest': 'Way',
#     'null': '31',
#     'top': [{'item': 'Street', 'count': '6612'},
#      {'item': 'Avenue', 'count': '1186'},
#      {'item': 'Drive', 'count': '691'},
#      {'item': 'Boulevard', 'count': '356'},
#      {'item': 'Place', 'count': '145'},
#      {'item': 'Road', 'count': '141'},
#      {'item': 'Court', 'count': '80'},
#      {'item': 'Highway', 'count': '35'},
#      {'item': 'Lane', 'count': '18'},
#      {'item': 'Parkway', 'count': '15'},
#      {'item': 'Circle', 'count': '10'},
#      {'item': 'Trail', 'count': '5'},
#      {'item': 'Terrace', 'count': '4'},
#      {'item': 'Way', 'count': '3'},
#      {'item': 'Roadway', 'count': '1'},
#      {'item': 'Trace', 'count': '1'}],
#     'smallest': 'Avenue',
#     'count': '9334',
#     'cardinality': '16'},
#    'format': {}},
#   {'id': 616490743,
#    'name': 'Location',
#    'dataTypeName': 'point',
#    'description': '',
#    'fieldName': 'location_2',
#    'position': 99,
#    'renderTypeName': 'point',
#    'tableColumnId': 161165406,
#    'cachedContents': {'non_null': '9334',
#     'null': '0',
#     'top': [{'item': {'coordinates': [-90.0213012704071, 30.0139007574917],
#        'type': 'Point'},
#       'count': '2'},
#      {'item': {'coordinates': [-90.012530785, 29.977558335], 'type': 'Point'},
#       'count': '1'},
#      {'item': {'coordinates': [-90.10874408, 30.016742967], 'type': 'Point'},
#       'count': '1'},
#      {'item': {'coordinates': [-90.016845239, 29.978035876], 'type': 'Point'},
#       'count': '1'},
#      {'item': {'coordinates': [-90.025442676, 30.030870633], 'type': 'Point'},
#       'count': '1'},
#      {'item': {'coordinates': [-90.011755176, 29.970672872], 'type': 'Point'},
#       'count': '1'},
#      {'item': {'coordinates': [-90.022469434, 30.02590329], 'type': 'Point'},
#       'count': '1'},
#      {'item': {'coordinates': [-90.089346476, 29.944371222], 'type': 'Point'},
#       'count': '1'},
#      {'item': {'coordinates': [-90.011877017, 29.973869186], 'type': 'Point'},
#       'count': '1'},
#      {'item': {'coordinates': [-90.03580529, 29.928189498], 'type': 'Point'},
#       'count': '1'},
#      {'item': {'coordinates': [-90.087614662, 29.959320339], 'type': 'Point'},
#       'count': '1'},
#      {'item': {'coordinates': [-90.018074451, 29.966234757], 'type': 'Point'},
#       'count': '1'},
#      {'item': {'coordinates': [-90.036762877, 29.986780651], 'type': 'Point'},
#       'count': '1'},
#      {'item': {'coordinates': [-90.08206131, 29.964831605], 'type': 'Point'},
#       'count': '1'},
#      {'item': {'coordinates': [-89.958969361, 30.056723483], 'type': 'Point'},
#       'count': '1'},
#      {'item': {'coordinates': [-90.107965465, 29.97728745], 'type': 'Point'},
#       'count': '1'},
#      {'item': {'coordinates': [-90.093711289, 29.934940613], 'type': 'Point'},
#       'count': '1'},
#      {'item': {'coordinates': [-90.024661023, 29.965391932], 'type': 'Point'},
#       'count': '1'},
#      {'item': {'coordinates': [-90.003698357, 29.966550526], 'type': 'Point'},
#       'count': '1'},
#      {'item': {'coordinates': [-90.005707439, 29.968408365], 'type': 'Point'},
#       'count': '1'}],
#     'count': '9334',
#     'cardinality': '9333'},
#    'format': {}}],
#  'grants': [{'inherited': False, 'type': 'viewer', 'flags': ['public']}],
#  'license': {'name': 'Creative Commons 1.0 Universal (Public Domain Dedication)',
#   'logoUrl': 'images/licenses/ccZero.png',
#   'termsLink': 'http://creativecommons.org/publicdomain/zero/1.0/legalcode'},
#  'metadata': {'custom_fields': {'Common Core': {'Contact Email': 'data@nola.gov',
#     'Public Access Level': 'public'},
#    'Source Information': {'Source Department': 'Information Technology and Innovation - Enterprise GIS',
#     'Format': 'Shapefile',
#     'Frequency of Data Change': 'No change'}},
#   'availableDisplayTypes': ['table', 'fatrow', 'page']},
#  'owner': {'id': 'wvd3-542u',
#   'displayName': 'Christopher Ard',
#   'screenName': 'Christopher Ard',
#   'type': 'interactive',
#   'flags': ['acceptedEula', 'mayBeStoriesCoOwner']},
#  'query': {},
#  'rights': ['read'],
#  'tableAuthor': {'id': 'wvd3-542u',
#   'displayName': 'Christopher Ard',
#   'screenName': 'Christopher Ard',
#   'type': 'interactive',
#   'flags': ['acceptedEula', 'mayBeStoriesCoOwner']},
#  'flags': ['default',
#   'ownerMayBeContacted',
#   'restorable',
#   'restorePossibleForType']}

# %%
nola_json = nola_client.get(nola_dataset_identifier)

def download_raw_dataset(domain, dataset_id, outfile):
    url = f"https://{domain}/resource/{dataset_id}.json"

    resp = requests.get(
        url,
        timeout=15
    )
    resp.raise_for_status()

    with open(outfile, "wb") as f:
        f.write(resp.content)

download_raw_dataset(nola_domain, nola_dataset_identifier, f"{nola_dataset_identifier}.json")

# %%
# Tokens are optional (`None` can be used instead), though requests will be rate limited.
#
# If you choose to use a token, run the following command on the terminal (or add it to your .bashrc)
# $ export SODAPY_APPTOKEN=<token>
load_dotenv()
socrata_token = os.getenv("NYC_SOCRATA_TOKEN")

# %%
# Dataset: https://{domain}/resource/{identifier}.json
# Metadata: https://{domain}/views/{identifier}.json
nyc_dataset_identifier = "fhrw-4uyv" # 311 data
# nyc_client = Socrata(nyc_domain, username=os.getenv("NYC_SOCRATA_USERNAME"), password=os.getenv("NYC_SOCRATA_PASSWORD"), app_token=os.getenv("NYC_SOCRATA_TOKEN"), timeout=60)
nyc_client = Socrata(nyc_domain, socrata_token, timeout=600) # Often takes longer than default 10 sec timeout to load
nyc_results = nyc_client.get(nyc_dataset_identifier)
nyc_df = pd.DataFrame.from_dict(nyc_results)
print("Domain: {domain:}\nSession: {session:}\nURI Prefix: {uri_prefix:}".format(**nyc_client.__dict__))
print(nyc_df.shape)
# Out:
# Domain: data.cityofnewyork.us
# Session: <requests.sessions.Session object at 0x00000205E3DEF460>
# URI Prefix: https://
# (1000, 50)

# %%
# Experimenting with smaller NOLA data
nola_domain = "data.nola.gov"
nola_dataset_identifier = "2mq3-p3xc" # ID from previous study that no longer works ("You don't have the security clearance to view this page.")
# nola_client = Socrata(nola_domain, username=os.getenv("nola_SOCRATA_USERNAME"), password=os.getenv("nola_SOCRATA_PASSWORD"), app_token=os.getenv("nola_SOCRATA_TOKEN"), timeout=60)
nola_client = Socrata(nola_domain, socrata_token)
nola_results = nola_client.get(nola_dataset_identifier)
nola_df = pd.DataFrame.from_dict(nola_results)
print("Domain: {domain:}\nSession: {session:}\nURI Prefix: {uri_prefix:}".format(**nola_client.__dict__))
print(nola_df.shape)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[9], line 5
#       3 # nola_client = Socrata(nola_domain, username=os.getenv("nola_SOCRATA_USERNAME"), password=os.getenv("nola_SOCRATA_PASSWORD"), app_token=os.getenv("nola_SOCRATA_TOKEN"), timeout=60)
#       4 nola_client = Socrata(nola_domain, socrata_token)
# ----> 5 nola_results = nola_client.get(nola_dataset_identifier)
#       6 nola_df = pd.DataFrame.from_dict(nola_results)
#       7 print("Domain: {domain:}\nSession: {session:}\nURI Prefix: {uri_prefix:}".format(**nola_client.__dict__))
#
# File c:\Users\jlcha\Python Projects\Big-Data\Big-Data-Final-Project\.venv\Lib\site-packages\sodapy\socrata.py:412, in Socrata.get(self, dataset_identifier, content_type, **kwargs)
#     409 params.update(kwargs)
#     410 params = utils.clear_empty_values(params)
# --> 412 response = self._perform_request(
#     413     "get", resource, headers=headers, params=params
#     414 )
#     415 return response
#
# File c:\Users\jlcha\Python Projects\Big-Data\Big-Data-Final-Project\.venv\Lib\site-packages\sodapy\socrata.py:555, in Socrata._perform_request(self, request_type, resource, **kwargs)
#     553 # handle errors
#     554 if response.status_code not in (200, 202):
# --> 555     utils.raise_for_status(response)
#     557 # when responses have no content body (ie. delete, set_permission),
#     558 # simply return the whole response
#     559 if not response.text:
#
# File c:\Users\jlcha\Python Projects\Big-Data\Big-Data-Final-Project\.venv\Lib\site-packages\sodapy\utils.py:30, in raise_for_status(response)
#      28 if more_info and more_info.lower() != response.reason.lower():
#      29     http_error_msg += ".\n\t{}".format(more_info)
# ---> 30 raise requests.exceptions.HTTPError(http_error_msg, response=response)
#
# HTTPError: 403 Client Error: Forbidden.
# 	You must be logged in to access this resource

# %%
# extract tree-related complaints
# Example on sodapy github that did not work because Chattanooga data changed
tree_related = pd.concat(
    [
        nyc_df.complaint_type.str.contains(r"[T|t]ree").value_counts(),
    ],
    axis=1,
    keys=["nyc"],
)
tree_related.div(tree_related.sum()).round(2)

# %%
nyc_df.head()
# Out:
#   unique_key             created_date agency                      agency_name  \
# 0   66932951  2025-11-24T02:06:15.000   NYPD  New York City Police Department
# 1   66927366  2025-11-24T02:05:57.000   NYPD  New York City Police Department
# 2   66927332  2025-11-24T02:05:27.000   NYPD  New York City Police Department
# 3   66927308  2025-11-24T02:04:27.000   NYPD  New York City Police Department
# 4   66931824  2025-11-24T02:03:41.000   NYPD  New York City Police Department
#
#             complaint_type                    descriptor  \
# 0      Noise - Residential              Loud Music/Party
# 1      Noise - Residential               Loud Television
# 2       Noise - Commercial              Loud Music/Party
# 3          Illegal Parking  Commercial Overnight Parking
# 4  Noise - Street/Sidewalk                  Loud Talking
#
#                 location_type incident_zip      incident_address  \
# 0  Residential Building/House        10306    1742 RICHMOND ROAD
# 1  Residential Building/House        10002    280 MADISON STREET
# 2            Store/Commercial        11103        42-12 BROADWAY
# 3             Street/Sidewalk        10470  343 EAST  238 STREET
# 4             Street/Sidewalk        11385  2025 WOODBINE STREET
#
#         street_name  ... closed_date resolution_description  \
# 0     RICHMOND ROAD  ...         NaN                    NaN
# 1    MADISON STREET  ...         NaN                    NaN
# 2          BROADWAY  ...         NaN                    NaN
# 3  EAST  238 STREET  ...         NaN                    NaN
# 4   WOODBINE STREET  ...         NaN                    NaN
#
#   resolution_action_updated_date vehicle_type facility_type  \
# 0                            NaN          NaN           NaN
# 1                            NaN          NaN           NaN
# 2                            NaN          NaN           NaN
# 3                            NaN          NaN           NaN
# 4                            NaN          NaN           NaN
#
#   bridge_highway_name bridge_highway_segment taxi_company_borough  \
# 0                 NaN                    NaN                  NaN
# 1                 NaN                    NaN                  NaN
# 2                 NaN                    NaN                  NaN
# 3                 NaN                    NaN                  NaN
# 4                 NaN                    NaN                  NaN
#
#   bridge_highway_direction road_ramp
# 0                      NaN       NaN
# 1                      NaN       NaN
# 2                      NaN       NaN
# 3                      NaN       NaN
# 4                      NaN       NaN
#
# [5 rows x 50 columns]

# %%
SCROLL_FILE = "last_scroll_id.txt"
DOMAIN_FILE = "socrata_domains.txt"

def load_state():
    """Load scroll ID + seen domains if resuming."""
    # Load scroll ID
    if os.path.exists(SCROLL_FILE):
        with open(SCROLL_FILE, "r") as f:
            scroll_id = f.read().strip()
            if scroll_id == "":
                scroll_id = "*"   # fallback
    else:
        scroll_id = "*"

    # Load seen domains set
    seen = set()
    if os.path.exists(DOMAIN_FILE):
        with open(DOMAIN_FILE, "r") as f:
            for line in f:
                seen.add(line.strip())

    return scroll_id, seen


def save_scroll_id(scroll_id):
    """Write latest scroll ID to disk so we can resume."""
    with open(SCROLL_FILE, "w") as f:
        f.write(scroll_id)


def get_all_domains_resume():
    url = "https://api.us.socrata.com/api/catalog" # Seems to be a catalog of all things accessible by the api
    limit = 1000 # Limit 1000 because it is small enough to avoid timeouts. 10000 gets timed out. Optimal would probably be between

    # Load previous state
    scroll_id, seen = load_state()

    print(f"Starting with scroll_id={scroll_id}, {len(seen)} domains already saved.")

    # Open output file in append mode
    with open(DOMAIN_FILE, "a") as f_out:

        while True:
            print(f"Fetching scroll_id={scroll_id} ...")

            params = {"scroll_id": scroll_id, "limit": limit}

            try:
                resp = requests.get(url, params=params, timeout=10)
                resp.raise_for_status()
            except Exception as e:
                print(f"Error: {e}, retrying in 5 seconds...")
                time.sleep(5)
                continue

            data = resp.json()
            results = data.get("results", [])

            if not results:
                print("Deep scroll completed or no more results.")
                break

            # Process results
            for item in results:
                metadata = item.get("metadata", {})
                domain = metadata.get("domain")

                if domain and domain not in seen:
                    f_out.write(domain + "\n")
                    f_out.flush()  # ensure immediate write
                    seen.add(domain)

            # Update scroll ID for next request
            next_scroll = results[-1].get("resource").get("id") # id of previous resource can be used to get next scroll
            if not next_scroll:
                print("Finished scrolling dataset.")
                break

            scroll_id = next_scroll
            save_scroll_id(scroll_id)  # persist checkpoint

            time.sleep(0.2) # Only to avoid timeouts, may not be necessary

    print(f"\nCompleted with {len(seen)} total domains.")
    return seen

# Getting all domains to find cities, as the original study was about the state of urban data across US cities, not just NY
domains = get_all_domains_resume() # 555 domains discovered amongst ~220k things in the catalog, but many are for same entity
# Out:
# Starting with scroll_id=*, 118 domains already saved.
# Fetching scroll_id=* ...
# Fetching scroll_id=26is-s4fm ...
# Fetching scroll_id=2auq-ndkr ...
# Fetching scroll_id=2fh6-vrts ...
# Fetching scroll_id=2k8a-dz2p ...
# Fetching scroll_id=2qsi-qheg ...
# Fetching scroll_id=2vhj-s442 ...
# Fetching scroll_id=322a-riji ...
# Fetching scroll_id=36ib-rtmu ...
# Fetching scroll_id=3b78-mfyi ...
# Fetching scroll_id=3fxc-nque ...
# Fetching scroll_id=3kbj-ypat ...
# Fetching scroll_id=3qys-jk4f ...
# Fetching scroll_id=3vft-99rh ...
# Fetching scroll_id=4292-pktu ...
# Fetching scroll_id=46zs-4ngp ...
# Fetching scroll_id=4bn5-jdm8 ...
# Fetching scroll_id=4g6s-ak9g ...
# Fetching scroll_id=4m2v-hzec ...
# Fetching scroll_id=4rka-uupg ...
# Fetching scroll_id=4w6e-7nqk ...
# Fetching scroll_id=52ny-36z2 ...
# Fetching scroll_id=576d-v5m3 ...
# Fetching scroll_id=5bn2-vnxz ...
# Fetching scroll_id=5g3x-yfbg ...
# Fetching scroll_id=5kp7-t9c8 ...
# Fetching scroll_id=5rei-mff9 ...
# Fetching scroll_id=5w2u-reag ...
# Fetching scroll_id=62vi-89fw ...
# Fetching scroll_id=67fg-g2q4 ...
# Fetching scroll_id=6c82-9j9k ...
# Fetching scroll_id=6gmt-hx8z ...
# Fetching scroll_id=6m6g-823g ...
# Fetching scroll_id=6rix-t7ed ...
# Fetching scroll_id=6w4q-ad7v ...
# Fetching scroll_id=72sw-3a9a ...
# Fetching scroll_id=77bm-xz7r ...
# Fetching scroll_id=7but-dfeg ...
# Fetching scroll_id=7ggg-h7t2 ...
# Fetching scroll_id=7m2s-eq2x ...
# Fetching scroll_id=7rm5-pqmc ...
# Fetching scroll_id=7w5x-6d4e ...
# Fetching scroll_id=82n3-5qnu ...
# Fetching scroll_id=876s-ggyi ...
# Fetching scroll_id=8c5r-et7h ...
# Fetching scroll_id=8ggv-qqd2 ...
# Fetching scroll_id=8ksr-ysxt ...
# Fetching scroll_id=8rha-pk4m ...
# Fetching scroll_id=8vrk-e2ck ...
# Fetching scroll_id=922z-vztx ...
# Fetching scroll_id=96w7-kyyx ...
# Fetching scroll_id=9bpk-kkmm ...
# Fetching scroll_id=9gfb-fi7z ...
# Fetching scroll_id=9kzb-v3x2 ...
# Fetching scroll_id=9ru5-dh4q ...
# Fetching scroll_id=9wbm-nxzj ...
# Fetching scroll_id=a2g3-5t6s ...
# Fetching scroll_id=a74x-7y2s ...
# Fetching scroll_id=absk-avps ...
# Fetching scroll_id=agd8-y9qj ...
# Fetching scroll_id=akue-crv5 ...
# Fetching scroll_id=areg-db7d ...
# Fetching scroll_id=avx4-zd6r ...
# Fetching scroll_id=b2ng-tnnv ...
# Fetching scroll_id=b79z-cp55 ...
# Fetching scroll_id=bbwp-rjvk ...
# Fetching scroll_id=bghm-sy9f ...
# Fetching scroll_id=bm7z-fkgj ...
# Fetching scroll_id=brpn-en8s ...
# Fetching scroll_id=bw4c-7fsg ...
# Fetching scroll_id=c2kz-revs ...
# Fetching scroll_id=c72x-zuje ...
# Fetching scroll_id=cbhq-kxn8 ...
# Fetching scroll_id=cg3p-dbv7 ...
# Fetching scroll_id=ckj3-hzzm ...
# Fetching scroll_id=cqw8-mph2 ...
# Fetching scroll_id=cvj5-7zeq ...
# Fetching scroll_id=d2c4-rc87 ...
# Fetching scroll_id=d6zi-awjw ...
# Fetching scroll_id=dbcg-pp4j ...
# Fetching scroll_id=dft7-65vg ...
# Fetching scroll_id=dkc4-xfw6 ...
# Fetching scroll_id=dr5h-ygze ...
# Fetching scroll_id=dvky-p565 ...
# Fetching scroll_id=e28h-tx85 ...
# Fetching scroll_id=e6pr-h8jz ...
# Fetching scroll_id=ebbz-q7sb ...
# Fetching scroll_id=efzp-guci ...
# Fetching scroll_id=ekfp-vbrh ...
# Fetching scroll_id=eqz9-vkvu ...
# Fetching scroll_id=evih-77iq ...
# Fetching scroll_id=f232-trny ...
# Fetching scroll_id=f6nm-jpum ...
# Fetching scroll_id=fb7h-3siu ...
# Fetching scroll_id=ffnm-86v5 ...
# Fetching scroll_id=fk7i-xuiy ...
# Fetching scroll_id=fr3h-t2an ...
# Fetching scroll_id=fvp5-hqgd ...
# Fetching scroll_id=g2g4-ayrq ...
# Fetching scroll_id=g6sg-2dum ...
# Fetching scroll_id=gbh9-eu9p ...
# Fetching scroll_id=gg97-ghvs ...
# Fetching scroll_id=gkjm-pz5b ...
# Fetching scroll_id=grcs-7v27 ...
# Fetching scroll_id=gvw4-busu ...
# Fetching scroll_id=h2hx-dr22 ...
# Fetching scroll_id=h6z9-jrrj ...
# Fetching scroll_id=hbp4-a42z ...
# Fetching scroll_id=hg7a-5ssi ...
# Fetching scroll_id=hks6-3369 ...
# Fetching scroll_id=hrfz-ifrx ...
# Fetching scroll_id=hw2e-4w8m ...
# Fetching scroll_id=i2q9-thny ...
# Fetching scroll_id=i766-p32v ...
# Fetching scroll_id=ibr9-yu5c ...
# Fetching scroll_id=ig9n-7w22 ...
# Fetching scroll_id=ikqm-mdcx ...
# Fetching scroll_id=irac-e9vd ...
# Fetching scroll_id=ivs6-8jcq ...
# Fetching scroll_id=j23x-i69i ...
# Fetching scroll_id=j6kh-jb97 ...
# Fetching scroll_id=jbad-r7gg ...
# Fetching scroll_id=jfsg-k3dk ...
# Fetching scroll_id=jk98-5z68 ...
# Fetching scroll_id=jqmz-ijpx ...
# Fetching scroll_id=jv7i-ymgx ...
# Fetching scroll_id=jzqe-uknz ...
# Fetching scroll_id=k6e3-ypu7 ...
# Fetching scroll_id=kb46-uwap ...
# Fetching scroll_id=kfn2-q5t2 ...
# Fetching scroll_id=kk8y-6cmt ...
# Fetching scroll_id=kqy6-pkkh ...
# Fetching scroll_id=kvc5-apzs ...
# Fetching scroll_id=kzz4-sxw3 ...
# Fetching scroll_id=m6qd-ivp6 ...
# Fetching scroll_id=mb89-xnkg ...
# Fetching scroll_id=mfrf-4jec ...
# Fetching scroll_id=mkpc-jtj2 ...
# Fetching scroll_id=mrch-db9m ...
# Fetching scroll_id=mvv8-fx2w ...
# Fetching scroll_id=n2cp-q5r4 ...
# Fetching scroll_id=n6yv-t986 ...
# Fetching scroll_id=nbhb-e4kk ...
# Fetching scroll_id=ng7b-7v7i ...
# Fetching scroll_id=nkhw-t33s ...
# Fetching scroll_id=nr9r-twgg ...
# Fetching scroll_id=nvzi-98zx ...
# Fetching scroll_id=p2qw-hzdr ...
# Fetching scroll_id=p7ab-86fy ...
# Fetching scroll_id=pbtu-kc4f ...
# Fetching scroll_id=pgbb-7sqy ...
# Fetching scroll_id=pkwi-y3im ...
# Fetching scroll_id=prr2-5x3z ...
# Fetching scroll_id=pwd3-9ixs ...
# Fetching scroll_id=q2xn-dbar ...
# Fetching scroll_id=q7db-sz7e ...
# Fetching scroll_id=qbqi-u7ub ...
# Fetching scroll_id=qg8r-wtcc ...
# Fetching scroll_id=qkth-ixix ...
# Fetching scroll_id=qrf5-sm4d ...
# Fetching scroll_id=qvr3-hujm ...
# Fetching scroll_id=r2a9-6x27 ...
# Fetching scroll_id=r6z9-e9sk ...
# Fetching scroll_id=rbnz-6r8d ...
# Fetching scroll_id=rgb2-vg49 ...
# Fetching scroll_id=rkuw-9d8q ...
# Fetching scroll_id=rrk2-nny6 ...
# Fetching scroll_id=rw2k-auj2 ...
# Fetching scroll_id=s2fv-7nn3 ...
# Fetching scroll_id=s77b-fkvt ...
# Fetching scroll_id=sbt8-zbt3 ...
# Fetching scroll_id=sgaf-dgwh ...
# Fetching scroll_id=skur-ide6 ...
# Fetching scroll_id=srcg-pk3c ...
# Fetching scroll_id=sw7f-g3c8 ...
# Fetching scroll_id=t2ny-ab25 ...
# Fetching scroll_id=t785-g6c2 ...
# Fetching scroll_id=tbpb-gyqs ...
# Fetching scroll_id=tg8v-tm6u ...
# Fetching scroll_id=tkun-uh43 ...
# Fetching scroll_id=trgm-jf96 ...
# Fetching scroll_id=tw9f-pfq7 ...
# Fetching scroll_id=u2se-stek ...
# Fetching scroll_id=u79r-ikfz ...
# Fetching scroll_id=uc5t-qwnd ...
# Fetching scroll_id=ugvt-zfhv ...
# Fetching scroll_id=umhb-sira ...
# Fetching scroll_id=uryh-z79n ...
# Fetching scroll_id=uwvr-5vqt ...
# Fetching scroll_id=v3i8-wbra ...
# Fetching scroll_id=v885-xbg9 ...
# Fetching scroll_id=vcyb-y46t ...
# Fetching scroll_id=vhbn-mfe4 ...
# Fetching scroll_id=vn2j-nnhe ...
# Fetching scroll_id=vsh5-8jzw ...
# Fetching scroll_id=vx9h-aax8 ...
# Fetching scroll_id=w3m4-pvuy ...
# Fetching scroll_id=w86v-fpnz ...
# Fetching scroll_id=wcwi-aeif ...
# Fetching scroll_id=whpw-w55x ...
# Fetching scroll_id=wnic-imer ...
# Fetching scroll_id=wt73-gb3j ...
# Fetching scroll_id=wxqu-nncd ...
# Fetching scroll_id=x4g4-j86v ...
# Fetching scroll_id=x8x7-g8dg ...
# Fetching scroll_id=xdcz-tf7r ...
# Fetching scroll_id=xhwt-7h2h ...
# Fetching scroll_id=xna5-9s6i ...
# Fetching scroll_id=xsu4-4sk9 ...
# Fetching scroll_id=xxfr-9j4p ...
# Fetching scroll_id=y3xp-i4gw ...
# Fetching scroll_id=y8ma-vcbx ...
# Fetching scroll_id=ycw8-y9a9 ...
# Fetching scroll_id=yhnd-ye3z ...
# Fetching scroll_id=yney-zfys ...
# Fetching scroll_id=ysr4-wjms ...
# Fetching scroll_id=zzan-2jsq ...
# Deep scroll completed or no more results.
#
# Completed with 555 total domains.

# %%
def filter_lines(input_path: str, output_path: str, include: str | None = None, exclude: str | None = None):
    with open(input_path, "r", encoding="utf-8") as infile, \
         open(output_path, "w", encoding="utf-8") as outfile:
        
        for line in infile:
            # If include phrase is given, skip lines that don't contain it
            if include is not None and include not in line:
                continue
            
            # If exclude phrase is given, skip lines that DO contain it
            if exclude is not None and exclude in line:
                continue
            
            outfile.write(line)

# %%
def filter_lines_start(input_path: str, output_path: str, include_start: str | None = None, exclude_start: str | None = None):
    with open(input_path, "r", encoding="utf-8") as infile, \
         open(output_path, "w", encoding="utf-8") as outfile:
        
        for line in infile:
            # Check include-start condition
            if include_start is not None and not line.startswith(include_start):
                continue

            # Check exclude-start condition
            if exclude_start is not None and line.startswith(exclude_start):
                continue

            outfile.write(line)

# %%
filter_lines_start("socrata_domains.txt", "socrata_domains_data.txt", include_start="data.")

# %%
filter_lines("socrata_domains_data.txt", "socrata_domains_countyless.txt", exclude="county")

# %%
def normalize_url(url: str) -> str:
    if not url.startswith(("http://", "https://")):
        return "https://" + url
    return url

def find_city(input_path: str, output_path: str, phrase: str): # Didn't even get all the cities
    print("Not city:")
    with open(input_path, "r", encoding="utf-8") as infile, \
         open(output_path, "w", encoding="utf-8") as outfile:
        
        for line in infile:
            text = ""
            response = requests.get(normalize_url(line.strip()))
            
            if response.ok:

                soup = BeautifulSoup(response.text, "html.parser")

                # Try meta name="title"
                meta_title = soup.find("meta", attrs={"name": "title"}) # Probably need more checks to properly find cities
                if meta_title is not None and "content" in meta_title.attrs:
                    text = meta_title["content"]

                # Fallback to the <title> tag
                elif soup.title:
                    text = soup.title.text.strip()

            if phrase in text.lower():
                outfile.write(line)
            else:
                print(line)

# %%
find_city("socrata_domains_countyless.txt", "socrata_domains_cities_only.txt", phrase="city")
# Out:
# Not city:
# data.cityofnewyork.us
#
# data.auburnwa.gov
#
# data.cambridgema.gov
#
# data.novascotia.ca
#
# data.honolulu.gov
#
# data.bayareametro.gov
#
# data.cdc.gov
#
# data.calgary.ca
#
# data.bts.gov
#
# data.pa.gov
#
# data.edmonton.ca
#
# data.dumfriesva.gov
#
# data.cityofgainesville.org
#
# data.delaware.gov
#
# data.oce.pr.gov
#
# data.kcmo.org
#
# data.cincinnati-oh.gov
#
# data.buffalony.gov
#
# data.mmcp.ms.gov
#
# data.wcad.org
#
# data.memphistn.gov
#
# data.readingpa.gov
#
# data.framinghamma.gov
#
# data.smcgov.org
#
# data.vermont.gov
#
# data.datacenterresearch.org
#
# data.tompsc.com
#
# data.orcities.org
#
# data.stocktonca.gov
#
# data.cstx.gov
#
# data.coloradosprings.gov
#
# data.sfgov.org
#
# data.nhitc.org
#
# data.fortworthtexas.gov
#
# data.qac.org
#
# data.oxnard.org

# %% [markdown]
# # Metadata needed
#
# - Schema: "columns" | list of columns
#
# - Column Types: "dataTypeName" | in the list of columns
#
# - Column Names: "name" or "fieldName" | in the list of columns
#
# - Zipcode: convert from lat long like the previous study, but no uniform way to get location
#
# - Nulls: "non_null" and "null" | in "cachedContents" in the list of columns, but seemingly not for all datasets, so may need to download
#
# - Category: "category" | for top categories of each city
#
# - Format: "displayType" or "viewType"
#
# - Number of Rows: May need to download the data
#
# - Tags: "tags" | list of tags
#
# - Number of Downloads: "downloadCount"
#
# - Number of Views: "viewCount"
#
# - Age of Dataset: "createdAt"
#
# - Update Frequency: "indexUpdatedAt" or "rowsUpdatedAt"
